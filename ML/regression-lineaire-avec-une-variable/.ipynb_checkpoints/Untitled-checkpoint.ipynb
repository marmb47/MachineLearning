# %% [markdown]
# # Introduction

# %% [markdown]
# à remplir

# %% [markdown]
# # 1 - Représentation du modèle et fonction d'erreur

# %% [markdown]
# Nous allons réaliser un modèle qui permet de prédire le profit d'un food-truck connaissant la nombre d'habitants de la ville ou il sera stationné. Pour se faire, nous disposons d'un dataset qui contient les profits de plusieurs food-truck stationnés sur plusieurs villes différents.

# %% [markdown]
# ## 1.1 - Comprendre le dataset

# %% [markdown]
# le dataset a été téléchargé depuis Coursera. Il s'agit de d'un fichier csv (food-truck_profits.txt) qui contient deux champs qui portent sur les profits de différents food truck dans des villes. Chaque ligne représente un food truck dans une ville.
# Les deux champs sont :
# - le premier champ représente le nombre d'habitant de la ville.
# - le deuxième champ représente le profit (en dollars) d'un food truck sur cette ville.

# %% [markdown]
# Maintenant, allons recupérer ces deux champs et voir à quoi ils resembles

# %%
import numpy as np
tab = np.genfromtxt('food-truck_profits.txt', delimiter=',')

# recuperation des nombres d'habitants des villes
X = tab[:,0];

# recuperation des profits des food truck respectivement sur ces villes
Y = tab[:,1];

dataset = np.ones((np.size(X),2))
dataset[:,0] = X
dataset[:,1] = Y

# on affiche les 10 premiers food truck
print(dataset[0:9,:])
# Out:
# [[ 6.1101 17.592 ]
#  [ 5.5277  9.1302]
#  [ 8.5186 13.662 ]
#  [ 7.0032 11.854 ]
#  [ 5.8598  6.8233]
#  [ 8.3829 11.886 ]
#  [ 7.4764  4.3483]
#  [ 8.5781 12.    ]
#  [ 6.4862  6.5987]]

# %% [markdown]
# On a recupérer les nombres d'habitants des villes X et les profits des food truck correspondant Y qu'on a mis sur un tableau à deux colonnes qui se nomme "dataset".
# le prémière colonne représente les nombres d'habitants des villes et la deuxieme colonne représente les profits des food truc sur ces villes. On nomme m le nombre d'exemples (de food trucks) dans le dataset.
# On obtient ainsi l'ensemble $$E_m = \{(x^{(1)},y^{(1)}),(x^{(2)},y^{(2)}),...,(x^{(m)},y^{(m)})\} $$

# %% [markdown]
# De ce faite $$ (x^{(i)}, y^{(i)}) $$ représente la i-ème ligne dela table "dataset" : la nombres d'habitant de la i-ème ville et le profits de la i-ème food truck dans cette ville.

# %% [markdown]
# si on visualise le dataset, on aura :

# %%
import matplotlib.pyplot as plt

plt.plot(dataset[:,0], dataset[:,1], 'rx')
plt.show()

# %% [markdown]
# ## 1.2 - Représenter le modèle :

# %% [markdown]
# ### 1.2.1 -Représentation du modèle :

# %% [markdown]
# Nous avons maintenant notre dataset qui represente les profits des food truck en sachant le nombre d'habitants de la ville les accueillant. Pour realiser le modele de regression linéaire, il ne faut trouver (apprendre) une fonction $$ h_\Theta : X \rightarrow Y $$

# %% [markdown]
# la fonction est appelé h (comme hypothese) par convention.
# toujours par convention, on met theta pour faire référence aux paramètres de la fonction.

# %% [markdown]
# Comme on fait une regression linéaire, la fonction h sera linéaire et est représenté par $$ h_\Theta (x) = \Theta_0 + \Theta_1 x$$

# %% [markdown]
# Pour que notre modele soit pertinant, la condition suivante doit etre vrai : pour tout $$ (x^{(i)}, y^{(i)}) \in E_m $$ on a $$ h_\Theta (x^{(i)}) \approx y^{(i)} $$

# %% [markdown]
# Pour que la condition ci-dessus soit vrai, il nous faut trouvé des valeurs adéquat pour les paramettres (Theta_0 et Theta_1) de la fonction.

# %% [markdown]
# Maintenant, la question qu'on peut se poser est "comment trouver les bonnes valeurs pour les parametres Theta_0 et Theta_1 ?".
# Nous allons y répondre dans la dernière partie de cette article mais avant ca, on va voir la fonction d'erreur.

# %% [markdown]
# ### 1.2.2 - Implémentation vectorielle du modèle :

# %% [markdown]
# Pour rendre notre fonction h plus performant en temps de calcule, on peut le vectoriser. Selon wikipedia, "La vectorisation est le processus de conversion d'un programme informatique à partir d'une implémentation scalaire, qui traite une seule paire d'opérandes à la fois, à une implémentation vectorielle qui traite une opération sur plusieurs paires d'opérandes à la fois."

# %% [markdown]
# Pour implémenter véctoriellement notre modèle, on doit définir la fonction h_theta de manière vectorielle.

# %% [markdown]
# Pour definir la fonction h_theta de maniere vectorielle :
# - On transforme d'abord les parametres theta en vecteur $$ \Theta =\binom{\Theta_0}{\Theta_1} $$

# %% [markdown]
# - Ensuite, on transforme x en vecteur $$ x =\binom{x_0}{x_1} \hspace{0.3cm} avec \hspace{0.3cm} x_0=1 \hspace{0.3cm} et \hspace{0.3cm} x_1=\hspace{0.1cm}nombre \hspace{0.2cm} d'habitants $$

# %% [markdown]
# la fonction h_theta devient $$ h_\Theta (x) = \Theta^T x $$

# %% [markdown]
# $$ avec \hspace{0.2cm}\Theta^T = vecteur \hspace{0.2cm}transposé \hspace{0.2cm} de \hspace{0.2cm} \Theta$$

# %% [markdown]
# Dans le reste de l'article et de la série, on implémentera toujours les modèles de manière vectorielle

# %% [markdown]
# $$ Pour \hspace{0.2cm} tous \hspace{0.2cm} les \hspace{0.2cm} x^{(i)} \in X \hspace{0.2cm} on \hspace{0.2cm} aura \hspace{0.2cm} x^{(i)} =\binom{x^{(i)}_0}{x^{(i)}_1} \hspace{0.2cm} avec \hspace{0.2cm} x^{(i)}_0=1 \hspace{0.2cm} et \hspace{0.2cm} x^{(i)}_1=x_1 $$

# %% [markdown]
# L'ensemble X des surfaces des maisons va devenir : $$ X = \begin{bmatrix}
# 1 & x^{(1)}_1\\
# 1 & x^{(2)}_1\\
#  .&. \\
#  .&. \\
#  .&. \\
# 1 & x^{(n)}_1
# \end{bmatrix} $$

# %% [markdown]
# on modifie la varable dataset afin d'ajouter une colonne (avec des 1) devant. ce qui va nous donner :

# %%
datasetTemp = dataset

dataset = np.ones((np.size(X),3))
dataset[:,1] = datasetTemp[:,0]
dataset[:,2] = datasetTemp[:,1]

X = dataset[:,0:2]
Y = dataset[:,2]

print(X.shape)
print(X)
print(Y.shape)
print(Y)
# Out:
# (97, 2)
# [[ 1.      6.1101]
#  [ 1.      5.5277]
#  [ 1.      8.5186]
#  [ 1.      7.0032]
#  [ 1.      5.8598]
#  [ 1.      8.3829]
#  [ 1.      7.4764]
#  [ 1.      8.5781]
#  [ 1.      6.4862]
#  [ 1.      5.0546]
#  [ 1.      5.7107]
#  [ 1.     14.164 ]
#  [ 1.      5.734 ]
#  [ 1.      8.4084]
#  [ 1.      5.6407]
#  [ 1.      5.3794]
#  [ 1.      6.3654]
#  [ 1.      5.1301]
#  [ 1.      6.4296]
#  [ 1.      7.0708]
#  [ 1.      6.1891]
#  [ 1.     20.27  ]
#  [ 1.      5.4901]
#  [ 1.      6.3261]
#  [ 1.      5.5649]
#  [ 1.     18.945 ]
#  [ 1.     12.828 ]
#  [ 1.     10.957 ]
#  [ 1.     13.176 ]
#  [ 1.     22.203 ]
#  [ 1.      5.2524]
#  [ 1.      6.5894]
#  [ 1.      9.2482]
#  [ 1.      5.8918]
#  [ 1.      8.2111]
#  [ 1.      7.9334]
#  [ 1.      8.0959]
#  [ 1.      5.6063]
#  [ 1.     12.836 ]
#  [ 1.      6.3534]
#  [ 1.      5.4069]
#  [ 1.      6.8825]
#  [ 1.     11.708 ]
#  [ 1.      5.7737]
#  [ 1.      7.8247]
#  [ 1.      7.0931]
#  [ 1.      5.0702]
#  [ 1.      5.8014]
#  [ 1.     11.7   ]
#  [ 1.      5.5416]
#  [ 1.      7.5402]
#  [ 1.      5.3077]
#  [ 1.      7.4239]
#  [ 1.      7.6031]
#  [ 1.      6.3328]
#  [ 1.      6.3589]
#  [ 1.      6.2742]
#  [ 1.      5.6397]
#  [ 1.      9.3102]
#  [ 1.      9.4536]
#  [ 1.      8.8254]
#  [ 1.      5.1793]
#  [ 1.     21.279 ]
#  [ 1.     14.908 ]
#  [ 1.     18.959 ]
#  [ 1.      7.2182]
#  [ 1.      8.2951]
#  [ 1.     10.236 ]
#  [ 1.      5.4994]
#  [ 1.     20.341 ]
#  [ 1.     10.136 ]
#  [ 1.      7.3345]
#  [ 1.      6.0062]
#  [ 1.      7.2259]
#  [ 1.      5.0269]
#  [ 1.      6.5479]
#  [ 1.      7.5386]
#  [ 1.      5.0365]
#  [ 1.     10.274 ]
#  [ 1.      5.1077]
#  [ 1.      5.7292]
#  [ 1.      5.1884]
#  [ 1.      6.3557]
#  [ 1.      9.7687]
#  [ 1.      6.5159]
#  [ 1.      8.5172]
#  [ 1.      9.1802]
#  [ 1.      6.002 ]
#  [ 1.      5.5204]
#  [ 1.      5.0594]
#  [ 1.      5.7077]
#  [ 1.      7.6366]
#  [ 1.      5.8707]
#  [ 1.      5.3054]
#  [ 1.      8.2934]
#  [ 1.     13.394 ]
#  [ 1.      5.4369]]
# (97,)
# [17.592    9.1302  13.662   11.854    6.8233  11.886    4.3483  12.
#   6.5987   3.8166   3.2522  15.505    3.1551   7.2258   0.71618  3.5129
#   5.3048   0.56077  3.6518   5.3893   3.1386  21.767    4.263    5.1875
#   3.0825  22.638   13.501    7.0467  14.692   24.147   -1.22     5.9966
#  12.134    1.8495   6.5426   4.5623   4.1164   3.3928  10.117    5.4974
#   0.55657  3.9115   5.3854   2.4406   6.7318   1.0463   5.1337   1.844
#   8.0043   1.0179   6.7504   1.8396   4.2885   4.9981   1.4233  -1.4211
#   2.4756   4.6042   3.9624   5.4141   5.1694  -0.74279 17.929   12.054
#  17.054    4.8852   5.7442   7.7754   1.0173  20.992    6.6799   4.0259
#   1.2784   3.3411  -2.6807   0.29678  3.8845   5.7014   6.7526   2.0576
#   0.47953  0.20421  0.67861  7.5435   5.3436   4.2415   6.7981   0.92695
#   0.152    2.8214   1.8451   4.2959   7.2029   1.9869   0.14454  9.0551
#   0.61705]

# %% [markdown]
# On peut ainsi implémenter la fonction python qui correspond à h_theta. Cette fonction prend en parametre deux vecteurs x (ou une matrice mx2) et theta et retourne la valeur de h_theta de x.

# %%
def h_theta(X, theta):
    ret = np.dot(theta, X.T)
    return ret

# %% [markdown]
# allons voir ce que donne la fonction h_theta sur des exemples :

# %%
# pour theta = (0.5, 1)
theta = np.array([0.5, 1])

x = np.array([1, 6.1101])
print("pour theta = (0.5, 1), et x = (1, 6.1101) h_theta(x) vaut : ", h_theta(x,theta))

print("pour theta = (0.5, 1), et X est le dataset,  h_theta(x) vaut : ", h_theta(X,theta))
# Out:
# pour theta = (0.5, 1), et x = (1, 6.1101) h_theta(x) vaut :  6.6101
# pour theta = (0.5, 1), et X est le dataset,  h_theta(x) vaut :  [ 6.6101  6.0277  9.0186  7.5032  6.3598  8.8829  7.9764  9.0781  6.9862
#   5.5546  6.2107 14.664   6.234   8.9084  6.1407  5.8794  6.8654  5.6301
#   6.9296  7.5708  6.6891 20.77    5.9901  6.8261  6.0649 19.445  13.328
#  11.457  13.676  22.703   5.7524  7.0894  9.7482  6.3918  8.7111  8.4334
#   8.5959  6.1063 13.336   6.8534  5.9069  7.3825 12.208   6.2737  8.3247
#   7.5931  5.5702  6.3014 12.2     6.0416  8.0402  5.8077  7.9239  8.1031
#   6.8328  6.8589  6.7742  6.1397  9.8102  9.9536  9.3254  5.6793 21.779
#  15.408  19.459   7.7182  8.7951 10.736   5.9994 20.841  10.636   7.8345
#   6.5062  7.7259  5.5269  7.0479  8.0386  5.5365 10.774   5.6077  6.2292
#   5.6884  6.8557 10.2687  7.0159  9.0172  9.6802  6.502   6.0204  5.5594
#   6.2077  8.1366  6.3707  5.8054  8.7934 13.894   5.9369]

# %% [markdown]
# On voit que pour le premier exemple (food truck), la nombre d'habitants de la ville est 6.1101 et le profit est 17.592.
# Quand on se sert de notre modèle h_theta pour estimer le profit de ce food truck on trouve 6.6101, ce qui veut dire que notre modèle n'est pas encore au point.
# Pour qu'il soit au point il faudra l'entrainer avec notre dataset.

# %% [markdown]
# ## 1.3 - Fonction d'erreur :

# %% [markdown]
# On a vu que notre modèle fait des erreurs dans l'estimation des profits des food truck. en prenant l'exemple du premier food truck de notre dataset qui est 17.592, notre modèle l'estime à 6.1101.

# %% [markdown]
# On peut definir l'erreur de notre modèle sur la première maison par : $$ (h_\Theta (x^{(1)}) - y^{(1)})^2 = (6.1101 - 17.592)^2 =131.83 $$

# %% [markdown]
# Ce qui est un grosse erreur car le profit estimé est trés loin du profit réel.

# %% [markdown]
# On peut ainsi définir la fonction d'erreur comme la moyene des erreurs de notre modèle sur le dataset E_m
# Ce qui nous donne : $$ J(\Theta ) = \frac{1}{2m}\sum_{i=1}^{m}(h_\Theta (x^{(i)}) - y^{(i)})^2 $$

# %% [markdown]
# Cette fonction est aussi appelé erreur quadratique.

# %% [markdown]
# Par convension et pour faciliter le calcul du gradiant, on multiplie cette moyène par 1/2.

# %% [markdown]
# Lors de l'entrainement du modèle, c'est cette fonction J_theta qu'on va essayé de minimiser.
# Ce qui revient à trouver un vecteur de paramèttre theta=(theta_0, theta_1) pour lequel J_theta serait le plus proche de 0.

# %% [markdown]
# On peut ainsi implémenter la fonction python qui correspond à la fonction d'erreur J de theta. Cette fonction prend en parametre un vecteur x (ou une matrice mx2), un vecteur theta et un vecteur Y (ou un scalaire y_i) et retourne la valeur de J de theta.

# %%
def computeErrorFunction(x, y, theta):
    h_theta_de_x = h_theta(x,theta)
    vec_temp =  (h_theta_de_x - y)**2
    ret = np.sum(vec_temp)/(2*(y.size))
    return ret

# %% [markdown]
# on peut calculer l'erreur :

# %%
theta = np.array([0.5, 1])
print("pour theta = (0.5, 1), l'erreur est :", computeErrorFunction(X, Y, theta))

theta = np.array([12, 30])
print("pour theta = (500, 1000), l'erreur est :", computeErrorFunction(X, Y, theta))
# Out:
# pour theta = (0.5, 1), l'erreur est : 8.731188017156702
# pour theta = (500, 1000), l'erreur est : 37643.43989082003

# %% [markdown]
# On voit que l'erreur est plus petite avec theta = (0.5, 1) qu'avec theta = (500, 1000), donc notre modèle est plus performant avec le parametre theta = (0.5, 1).

# %% [markdown]
# # 2 - Entrainement du Modèle :

# %% [markdown]
# L'entrainement du modèle consiste à trouver le vecteur paramètre theta = (theta_0, theta_1) pour lequel la fonction d'erreur J(theta) est le plus proche de 0. Pour se faire, on doit minimiser la fonction J(theta) : $$ \underset{\Theta_{0}, \Theta_{1}}{min}J(\Theta) $$.

# %% [markdown]
# On minimise J(theta) en faisant une descente de gradient.

# %% [markdown]
# ## 2.1 - la descente de gradient :

# %% [markdown]
# La descente de gradient est un algorithme qui permet de trouver le minimum d'une focntion.

# %% [markdown]
# Si on veut trouver le minimum d'une fonction f(x) par exemple $$ \underset{x}{min}f(x) $$, calculer f(x) pour toutes les valeur possibles de x serait trés couteux en ressources informatique et en temps de calcul. Il existe un meilleur outils (largement utilisé en machine learning) qui s'appele la descente de gradient.

# %% [markdown]
# 1- La première etape de la descente de gradient est de choisir au hasard une valeur x_0 de départ pour x.
# 2- Ensuite, on calcule le gradient de la fonction f au point x_0 (qui est f'(x_0)). En effet, le gradient est un vecteur qui indique toujours la direction de la croissance maximale de la fonction. Le schéma suivant va illustrer ca :

# %% [markdown]
# ![desc-grad-1.png](attachment:desc-grad-1.png)

# %% [markdown]
# 3- Comme le gradient indique la direction de la valeur maximale de la fonction, donc pour avoire une nouvelle valeur de x qui nous permette de nous rapprocher de la valeur minimale de la fonction f(x) on fait un pas vers la direction inverse du gradient. ce qui nous donne une nouvelle valeur x_1 = x_0 - alpha*f'(x_0).

# %% [markdown]
# 4- on repéte les etapes 1, 2, et 3 avec la nouvelle valeur de x_1 de x.
# 5- En iterant plusieurs fois sur ce procédé, on va arriver à une valeur x_n tel que $$ f(x_{n}) \approx 0 $$

# %% [markdown]
# Et la, on dit qu'on a atteint notre point de convergence.

# %% [markdown]
# ![desc-grad-2.png](attachment:desc-grad-2.png)

# %% [markdown]
# alpha est un paramètre de l'algorithme de descente de gradient. On l'appelle le pas d'apprentissage (learning rate en anglais).
# la valeur de alpha doit etre fixé avant le debut de la descente de grandient. Il ne doit ni trop petit ni trop grand.

# %% [markdown]
# ## 2.2 - Application de la descente de gradient à notre modèle de regression linéaire :

# %% [markdown]
# L'entrainement du modèle consiste à minimiser la fonction d'erreur : $$ \underset{\Theta_{0}, \Theta_{1}}{min}J(\Theta) $$.

# %% [markdown]
# Pour se faire, nous allons appliquer le descente de gradient sur la fonction J(theta).
# Dans le cas de notre fonction J(theta), on a deux inconnues theta_0 et theta_1. au lieu de calculer J'(theta), on calcule les dérivés partiels $$ \frac{\partial}{\partial \Theta_0}J(\Theta) \hspace{0.2cm} et \hspace{0.2cm} \frac{\partial}{\partial \Theta_1}J(\Theta)$$

# %% [markdown]
# qui sont  : $$ \frac{\partial}{\partial \Theta_0}J(\Theta) = \frac{1}{m}\sum_{i=1}^{m}\left ( h_\Theta (x^{(i)}) - y^{(i)} \right ) $$

# %% [markdown]
# $$ \frac{\partial}{\partial \Theta_1}J(\Theta) = \frac{1}{m}\sum_{i=1}^{m}(\left ( h_\Theta (x^{(i)}) - y^{(i)} \right )x^{(i)}_1) $$

# %% [markdown]
# Dabord, on choisi des valeurs initiaux (au hasarrd) pour theta_0 et theta_1

# %% [markdown]
# Ensuite, on fait des itérations :

# %% [markdown]
# on a : repeter { $$ \Theta_0 := \Theta_0 - \alpha \frac{1}{m}\sum_{i=1}^{m}\left ( h_\Theta (x^{(i)}) - y^{(i)} \right ) $$

# %% [markdown]
# $$ \Theta_1 := \Theta_1 - \alpha \frac{1}{m}\sum_{i=1}^{m}(\left ( h_\Theta (x^{(i)}) - y^{(i)} \right )x^{(i)}_1) $$

# %% [markdown]
# }

# %% [markdown]
# En machine learning, chaque itération est appelé epoque. le nombre d'époque est un paramèttre de l'apprentissage.

# %% [markdown]
# Pour implémenter véctoriellement l'entrainement de notre modèle, On transforme les parametres theta et les gradients (dérivés partielles) en vecteur $$ \Theta =\binom{\Theta_0}{\Theta_1} \hspace{0.2cm} et \hspace{0.2cm} \triangledown J(\Theta ) = \binom{\frac{\partial}{\partial \Theta_0}J(\Theta)}{\frac{\partial}{\partial \Theta_1}J(\Theta)}$$

# %% [markdown]
# Notre itération devient :  repeter { $$ \Theta := \Theta - \alpha \hspace{0.1cm} \triangledown J(\Theta ) $$

# %% [markdown]
# }

# %% [markdown]
# On peut ainsi implémenter la fonction python qui calcule les gradients. Cette fonction prend en parametre un vecteur une matrice mx2, un vecteur theta et un vecteur Y et retourne le vercteur de gradient $$ \triangledown J(\Theta ) $$.

# %%
def computeGradient(x, y, theta):
    h_theta_de_x = h_theta(x,theta)
    vec_temp =  (h_theta_de_x - y)
    ret = np.dot(x.T,vec_temp)/y.size
    return ret

# %% [markdown]
# on peut calculer le vecteur des gradients pour voir ce que ca donne :

# %%
theta = np.array([0.5, 1])
print("pour theta = (0.5, 1), le vecteur des gradients est :", computeGradient(X, Y, theta))
# Out:
# pour theta = (0.5, 1), le vecteur des gradients est : [ 2.82066495 20.15499308]

# %% [markdown]
# On peut aussi implémenter la fonction python qui entraine notre modèle. Cette fonction prend en parametre un vecteur une matrice mx2, un vecteur Y, le nombre d'epoques, et le learning rate (alpha) et retourne le vercteur de theta pour lequel notre fonction d'erreur sera minimum.

# %%
np.seterr(all='warn')
np.set_printoptions(suppress=True)
def trainModel(x, y, nb_epoch, alpha=0.01):
    # on choisi des valeurs arbitraires pour le vecteur theta
    theta = np.array([0.5, 1])
    # on itere sur le nombre d'epoques
    for i in range(nb_epoch):
        grad = computeGradient(x, y, theta)
        theta = theta - alpha*grad
        if i == 15 : 
            print("theta ", theta)
            print("gradient :", grad)
            print("h_theta : ",h_theta(x,theta))
            
        print("Epoque ", i)
        print("l'erreur est : ", "%.5f"%computeErrorFunction(x, y, theta))
    
    return theta

# %% [markdown]
# Entrainons notre modèle sur 1500 epoques par exemple. ce qui nous donne :

# %%
theta_train = trainModel(X, Y, 1500, 0.02)
# Out:
# Epoque  0
# l'erreur est :  7.24838
# Epoque  1
# l'erreur est :  6.62527
# Epoque  2
# l'erreur est :  6.35929
# Epoque  3
# l'erreur est :  6.24169
# Epoque  4
# l'erreur est :  6.18577
# Epoque  5
# l'erreur est :  6.15552
# Epoque  6
# l'erreur est :  6.13598
# Epoque  7
# l'erreur est :  6.12095
# Epoque  8
# l'erreur est :  6.10783
# Epoque  9
# l'erreur est :  6.09555
# Epoque  10
# l'erreur est :  6.08368
# Epoque  11
# l'erreur est :  6.07203
# Epoque  12
# l'erreur est :  6.06051
# Epoque  13
# l'erreur est :  6.04909
# Epoque  14
# l'erreur est :  6.03777
# theta  [0.22986788 0.77878763]
# gradient : [ 0.74358103 -0.10278896]
# h_theta :  [ 4.98833819  4.53477228  6.86404821  5.68387343  4.79340765  6.75836673
#   6.05239574  6.91038607  5.28124022  4.16632785  4.67729041 11.26061592
#   4.69543617  6.77822581  4.62277528  4.41927807  5.18716268  4.22512631
#   5.23716084  5.73651947  5.04986242 16.0158932   4.50548986  5.15655632
#   4.56374318 14.98399959 10.22015564  8.76304397 10.49117373 17.5212897
#   4.32037204  5.36161111  7.43225167  4.81832885  6.62457101  6.40830169
#   6.53485468  4.59598498 10.22638594  5.17781723  4.44069473  5.58987376
#   9.34791349  4.72635403  6.32364747  5.75388644  4.17847693  4.74792645
#   9.34168319  4.54559742  6.10208239  4.363439    6.01150939  6.15106813
#   5.1617742   5.18210056  5.11613724  4.62199649  7.4805365   7.59221465
#   7.10298026  4.26344267 16.80168993 11.84003391 14.99490262  5.85131277
#   6.68998917  8.20153809  4.51273259 16.07118713  8.12365933  5.94188577
#   4.90742216  5.85730944  4.14475543  5.32929142  6.10083633  4.15223179
#   8.23113202  4.20768147  4.69169798  4.27052963  5.17960844  7.83761063
#   5.30437022  6.86295791  7.37929411  4.90415125  4.52908713  4.17006603
#   4.67495405  6.17715752  4.80189643  4.36164779  6.68866523 10.66094944
#   4.46405836]
# Epoque  15
# l'erreur est :  6.02654
# Epoque  16
# l'erreur est :  6.01538
# Epoque  17
# l'erreur est :  6.00431
# Epoque  18
# l'erreur est :  5.99332
# Epoque  19
# l'erreur est :  5.98240
# Epoque  20
# l'erreur est :  5.97157
# Epoque  21
# l'erreur est :  5.96081
# Epoque  22
# l'erreur est :  5.95013
# Epoque  23
# l'erreur est :  5.93953
# Epoque  24
# l'erreur est :  5.92900
# Epoque  25
# l'erreur est :  5.91855
# Epoque  26
# l'erreur est :  5.90817
# Epoque  27
# l'erreur est :  5.89787
# Epoque  28
# l'erreur est :  5.88765
# Epoque  29
# l'erreur est :  5.87749
# Epoque  30
# l'erreur est :  5.86741
# Epoque  31
# l'erreur est :  5.85741
# Epoque  32
# l'erreur est :  5.84747
# Epoque  33
# l'erreur est :  5.83761
# Epoque  34
# l'erreur est :  5.82781
# Epoque  35
# l'erreur est :  5.81809
# Epoque  36
# l'erreur est :  5.80844
# Epoque  37
# l'erreur est :  5.79886
# Epoque  38
# l'erreur est :  5.78934
# Epoque  39
# l'erreur est :  5.77990
# Epoque  40
# l'erreur est :  5.77052
# Epoque  41
# l'erreur est :  5.76121
# Epoque  42
# l'erreur est :  5.75196
# Epoque  43
# l'erreur est :  5.74279
# Epoque  44
# l'erreur est :  5.73368
# Epoque  45
# l'erreur est :  5.72463
# Epoque  46
# l'erreur est :  5.71565
# Epoque  47
# l'erreur est :  5.70674
# Epoque  48
# l'erreur est :  5.69789
# Epoque  49
# l'erreur est :  5.68910
# Epoque  50
# l'erreur est :  5.68037
# Epoque  51
# l'erreur est :  5.67171
# Epoque  52
# l'erreur est :  5.66311
# Epoque  53
# l'erreur est :  5.65458
# Epoque  54
# l'erreur est :  5.64610
# Epoque  55
# l'erreur est :  5.63769
# Epoque  56
# l'erreur est :  5.62933
# Epoque  57
# l'erreur est :  5.62104
# Epoque  58
# l'erreur est :  5.61280
# Epoque  59
# l'erreur est :  5.60463
# Epoque  60
# l'erreur est :  5.59651
# Epoque  61
# l'erreur est :  5.58846
# Epoque  62
# l'erreur est :  5.58046
# Epoque  63
# l'erreur est :  5.57251
# Epoque  64
# l'erreur est :  5.56463
# Epoque  65
# l'erreur est :  5.55680
# Epoque  66
# l'erreur est :  5.54903
# Epoque  67
# l'erreur est :  5.54131
# Epoque  68
# l'erreur est :  5.53365
# Epoque  69
# l'erreur est :  5.52605
# Epoque  70
# l'erreur est :  5.51850
# Epoque  71
# l'erreur est :  5.51100
# Epoque  72
# l'erreur est :  5.50356
# Epoque  73
# l'erreur est :  5.49617
# Epoque  74
# l'erreur est :  5.48883
# Epoque  75
# l'erreur est :  5.48155
# Epoque  76
# l'erreur est :  5.47432
# Epoque  77
# l'erreur est :  5.46714
# Epoque  78
# l'erreur est :  5.46002
# Epoque  79
# l'erreur est :  5.45294
# Epoque  80
# l'erreur est :  5.44592
# Epoque  81
# l'erreur est :  5.43894
# Epoque  82
# l'erreur est :  5.43202
# Epoque  83
# l'erreur est :  5.42514
# Epoque  84
# l'erreur est :  5.41832
# Epoque  85
# l'erreur est :  5.41154
# Epoque  86
# l'erreur est :  5.40482
# Epoque  87
# l'erreur est :  5.39814
# Epoque  88
# l'erreur est :  5.39151
# Epoque  89
# l'erreur est :  5.38493
# Epoque  90
# l'erreur est :  5.37839
# Epoque  91
# l'erreur est :  5.37190
# Epoque  92
# l'erreur est :  5.36546
# Epoque  93
# l'erreur est :  5.35907
# Epoque  94
# l'erreur est :  5.35272
# Epoque  95
# l'erreur est :  5.34642
# Epoque  96
# l'erreur est :  5.34016
# Epoque  97
# l'erreur est :  5.33395
# Epoque  98
# l'erreur est :  5.32778
# Epoque  99
# l'erreur est :  5.32165
# Epoque  100
# l'erreur est :  5.31558
# Epoque  101
# l'erreur est :  5.30954
# Epoque  102
# l'erreur est :  5.30355
# Epoque  103
# l'erreur est :  5.29760
# Epoque  104
# l'erreur est :  5.29169
# Epoque  105
# l'erreur est :  5.28583
# Epoque  106
# l'erreur est :  5.28001
# Epoque  107
# l'erreur est :  5.27423
# Epoque  108
# l'erreur est :  5.26849
# Epoque  109
# l'erreur est :  5.26279
# Epoque  110
# l'erreur est :  5.25714
# Epoque  111
# l'erreur est :  5.25152
# Epoque  112
# l'erreur est :  5.24595
# Epoque  113
# l'erreur est :  5.24041
# Epoque  114
# l'erreur est :  5.23492
# Epoque  115
# l'erreur est :  5.22946
# Epoque  116
# l'erreur est :  5.22405
# Epoque  117
# l'erreur est :  5.21867
# Epoque  118
# l'erreur est :  5.21333
# Epoque  119
# l'erreur est :  5.20803
# Epoque  120
# l'erreur est :  5.20277
# Epoque  121
# l'erreur est :  5.19754
# Epoque  122
# l'erreur est :  5.19236
# Epoque  123
# l'erreur est :  5.18721
# Epoque  124
# l'erreur est :  5.18210
# Epoque  125
# l'erreur est :  5.17702
# Epoque  126
# l'erreur est :  5.17198
# Epoque  127
# l'erreur est :  5.16698
# Epoque  128
# l'erreur est :  5.16202
# Epoque  129
# l'erreur est :  5.15708
# Epoque  130
# l'erreur est :  5.15219
# Epoque  131
# l'erreur est :  5.14733
# Epoque  132
# l'erreur est :  5.14251
# Epoque  133
# l'erreur est :  5.13771
# Epoque  134
# l'erreur est :  5.13296
# Epoque  135
# l'erreur est :  5.12824
# Epoque  136
# l'erreur est :  5.12355
# Epoque  137
# l'erreur est :  5.11890
# Epoque  138
# l'erreur est :  5.11428
# Epoque  139
# l'erreur est :  5.10969
# Epoque  140
# l'erreur est :  5.10514
# Epoque  141
# l'erreur est :  5.10061
# Epoque  142
# l'erreur est :  5.09613
# Epoque  143
# l'erreur est :  5.09167
# Epoque  144
# l'erreur est :  5.08725
# Epoque  145
# l'erreur est :  5.08285
# Epoque  146
# l'erreur est :  5.07849
# Epoque  147
# l'erreur est :  5.07416
# Epoque  148
# l'erreur est :  5.06986
# Epoque  149
# l'erreur est :  5.06560
# Epoque  150
# l'erreur est :  5.06136
# Epoque  151
# l'erreur est :  5.05715
# Epoque  152
# l'erreur est :  5.05298
# Epoque  153
# l'erreur est :  5.04883
# Epoque  154
# l'erreur est :  5.04472
# Epoque  155
# l'erreur est :  5.04063
# Epoque  156
# l'erreur est :  5.03657
# Epoque  157
# l'erreur est :  5.03255
# Epoque  158
# l'erreur est :  5.02855
# Epoque  159
# l'erreur est :  5.02458
# Epoque  160
# l'erreur est :  5.02064
# Epoque  161
# l'erreur est :  5.01672
# Epoque  162
# l'erreur est :  5.01284
# Epoque  163
# l'erreur est :  5.00898
# Epoque  164
# l'erreur est :  5.00515
# Epoque  165
# l'erreur est :  5.00135
# Epoque  166
# l'erreur est :  4.99758
# Epoque  167
# l'erreur est :  4.99383
# Epoque  168
# l'erreur est :  4.99011
# Epoque  169
# l'erreur est :  4.98642
# Epoque  170
# l'erreur est :  4.98275
# Epoque  171
# l'erreur est :  4.97911
# Epoque  172
# l'erreur est :  4.97550
# Epoque  173
# l'erreur est :  4.97191
# Epoque  174
# l'erreur est :  4.96835
# Epoque  175
# l'erreur est :  4.96481
# Epoque  176
# l'erreur est :  4.96130
# Epoque  177
# l'erreur est :  4.95781
# Epoque  178
# l'erreur est :  4.95435
# Epoque  179
# l'erreur est :  4.95092
# Epoque  180
# l'erreur est :  4.94750
# Epoque  181
# l'erreur est :  4.94412
# Epoque  182
# l'erreur est :  4.94076
# Epoque  183
# l'erreur est :  4.93742
# Epoque  184
# l'erreur est :  4.93410
# Epoque  185
# l'erreur est :  4.93081
# Epoque  186
# l'erreur est :  4.92755
# Epoque  187
# l'erreur est :  4.92430
# Epoque  188
# l'erreur est :  4.92108
# Epoque  189
# l'erreur est :  4.91789
# Epoque  190
# l'erreur est :  4.91471
# Epoque  191
# l'erreur est :  4.91156
# Epoque  192
# l'erreur est :  4.90844
# Epoque  193
# l'erreur est :  4.90533
# Epoque  194
# l'erreur est :  4.90225
# Epoque  195
# l'erreur est :  4.89919
# Epoque  196
# l'erreur est :  4.89615
# Epoque  197
# l'erreur est :  4.89313
# Epoque  198
# l'erreur est :  4.89014
# Epoque  199
# l'erreur est :  4.88716
# Epoque  200
# l'erreur est :  4.88421
# Epoque  201
# l'erreur est :  4.88128
# Epoque  202
# l'erreur est :  4.87837
# Epoque  203
# l'erreur est :  4.87548
# Epoque  204
# l'erreur est :  4.87261
# Epoque  205
# l'erreur est :  4.86976
# Epoque  206
# l'erreur est :  4.86694
# Epoque  207
# l'erreur est :  4.86413
# Epoque  208
# l'erreur est :  4.86134
# Epoque  209
# l'erreur est :  4.85858
# Epoque  210
# l'erreur est :  4.85583
# Epoque  211
# l'erreur est :  4.85310
# Epoque  212
# l'erreur est :  4.85040
# Epoque  213
# l'erreur est :  4.84771
# Epoque  214
# l'erreur est :  4.84504
# Epoque  215
# l'erreur est :  4.84239
# Epoque  216
# l'erreur est :  4.83976
# Epoque  217
# l'erreur est :  4.83715
# Epoque  218
# l'erreur est :  4.83456
# Epoque  219
# l'erreur est :  4.83198
# Epoque  220
# l'erreur est :  4.82943
# Epoque  221
# l'erreur est :  4.82689
# Epoque  222
# l'erreur est :  4.82437
# Epoque  223
# l'erreur est :  4.82187
# Epoque  224
# l'erreur est :  4.81939
# Epoque  225
# l'erreur est :  4.81693
# Epoque  226
# l'erreur est :  4.81448
# Epoque  227
# l'erreur est :  4.81205
# Epoque  228
# l'erreur est :  4.80964
# Epoque  229
# l'erreur est :  4.80724
# Epoque  230
# l'erreur est :  4.80487
# Epoque  231
# l'erreur est :  4.80251
# Epoque  232
# l'erreur est :  4.80016
# Epoque  233
# l'erreur est :  4.79784
# Epoque  234
# l'erreur est :  4.79553
# Epoque  235
# l'erreur est :  4.79324
# Epoque  236
# l'erreur est :  4.79096
# Epoque  237
# l'erreur est :  4.78870
# Epoque  238
# l'erreur est :  4.78646
# Epoque  239
# l'erreur est :  4.78423
# Epoque  240
# l'erreur est :  4.78202
# Epoque  241
# l'erreur est :  4.77982
# Epoque  242
# l'erreur est :  4.77764
# Epoque  243
# l'erreur est :  4.77548
# Epoque  244
# l'erreur est :  4.77333
# Epoque  245
# l'erreur est :  4.77120
# Epoque  246
# l'erreur est :  4.76908
# Epoque  247
# l'erreur est :  4.76698
# Epoque  248
# l'erreur est :  4.76489
# Epoque  249
# l'erreur est :  4.76282
# Epoque  250
# l'erreur est :  4.76076
# Epoque  251
# l'erreur est :  4.75872
# Epoque  252
# l'erreur est :  4.75669
# Epoque  253
# l'erreur est :  4.75468
# Epoque  254
# l'erreur est :  4.75268
# Epoque  255
# l'erreur est :  4.75069
# Epoque  256
# l'erreur est :  4.74872
# Epoque  257
# l'erreur est :  4.74677
# Epoque  258
# l'erreur est :  4.74482
# Epoque  259
# l'erreur est :  4.74290
# Epoque  260
# l'erreur est :  4.74098
# Epoque  261
# l'erreur est :  4.73908
# Epoque  262
# l'erreur est :  4.73720
# Epoque  263
# l'erreur est :  4.73532
# Epoque  264
# l'erreur est :  4.73346
# Epoque  265
# l'erreur est :  4.73162
# Epoque  266
# l'erreur est :  4.72978
# Epoque  267
# l'erreur est :  4.72797
# Epoque  268
# l'erreur est :  4.72616
# Epoque  269
# l'erreur est :  4.72437
# Epoque  270
# l'erreur est :  4.72258
# Epoque  271
# l'erreur est :  4.72082
# Epoque  272
# l'erreur est :  4.71906
# Epoque  273
# l'erreur est :  4.71732
# Epoque  274
# l'erreur est :  4.71559
# Epoque  275
# l'erreur est :  4.71387
# Epoque  276
# l'erreur est :  4.71217
# Epoque  277
# l'erreur est :  4.71047
# Epoque  278
# l'erreur est :  4.70879
# Epoque  279
# l'erreur est :  4.70713
# Epoque  280
# l'erreur est :  4.70547
# Epoque  281
# l'erreur est :  4.70382
# Epoque  282
# l'erreur est :  4.70219
# Epoque  283
# l'erreur est :  4.70057
# Epoque  284
# l'erreur est :  4.69896
# Epoque  285
# l'erreur est :  4.69736
# Epoque  286
# l'erreur est :  4.69578
# Epoque  287
# l'erreur est :  4.69420
# Epoque  288
# l'erreur est :  4.69264
# Epoque  289
# l'erreur est :  4.69109
# Epoque  290
# l'erreur est :  4.68955
# Epoque  291
# l'erreur est :  4.68802
# Epoque  292
# l'erreur est :  4.68650
# Epoque  293
# l'erreur est :  4.68499
# Epoque  294
# l'erreur est :  4.68349
# Epoque  295
# l'erreur est :  4.68200
# Epoque  296
# l'erreur est :  4.68053
# Epoque  297
# l'erreur est :  4.67906
# Epoque  298
# l'erreur est :  4.67761
# Epoque  299
# l'erreur est :  4.67617
# Epoque  300
# l'erreur est :  4.67473
# Epoque  301
# l'erreur est :  4.67331
# Epoque  302
# l'erreur est :  4.67190
# Epoque  303
# l'erreur est :  4.67049
# Epoque  304
# l'erreur est :  4.66910
# Epoque  305
# l'erreur est :  4.66772
# Epoque  306
# l'erreur est :  4.66634
# Epoque  307
# l'erreur est :  4.66498
# Epoque  308
# l'erreur est :  4.66363
# Epoque  309
# l'erreur est :  4.66228
# Epoque  310
# l'erreur est :  4.66095
# Epoque  311
# l'erreur est :  4.65963
# Epoque  312
# l'erreur est :  4.65831
# Epoque  313
# l'erreur est :  4.65701
# Epoque  314
# l'erreur est :  4.65571
# Epoque  315
# l'erreur est :  4.65442
# Epoque  316
# l'erreur est :  4.65315
# Epoque  317
# l'erreur est :  4.65188
# Epoque  318
# l'erreur est :  4.65062
# Epoque  319
# l'erreur est :  4.64937
# Epoque  320
# l'erreur est :  4.64813
# Epoque  321
# l'erreur est :  4.64690
# Epoque  322
# l'erreur est :  4.64567
# Epoque  323
# l'erreur est :  4.64446
# Epoque  324
# l'erreur est :  4.64325
# Epoque  325
# l'erreur est :  4.64206
# Epoque  326
# l'erreur est :  4.64087
# Epoque  327
# l'erreur est :  4.63969
# Epoque  328
# l'erreur est :  4.63852
# Epoque  329
# l'erreur est :  4.63736
# Epoque  330
# l'erreur est :  4.63620
# Epoque  331
# l'erreur est :  4.63506
# Epoque  332
# l'erreur est :  4.63392
# Epoque  333
# l'erreur est :  4.63279
# Epoque  334
# l'erreur est :  4.63167
# Epoque  335
# l'erreur est :  4.63055
# Epoque  336
# l'erreur est :  4.62945
# Epoque  337
# l'erreur est :  4.62835
# Epoque  338
# l'erreur est :  4.62726
# Epoque  339
# l'erreur est :  4.62618
# Epoque  340
# l'erreur est :  4.62511
# Epoque  341
# l'erreur est :  4.62404
# Epoque  342
# l'erreur est :  4.62298
# Epoque  343
# l'erreur est :  4.62193
# Epoque  344
# l'erreur est :  4.62089
# Epoque  345
# l'erreur est :  4.61985
# Epoque  346
# l'erreur est :  4.61882
# Epoque  347
# l'erreur est :  4.61780
# Epoque  348
# l'erreur est :  4.61679
# Epoque  349
# l'erreur est :  4.61578
# Epoque  350
# l'erreur est :  4.61478
# Epoque  351
# l'erreur est :  4.61379
# Epoque  352
# l'erreur est :  4.61281
# Epoque  353
# l'erreur est :  4.61183
# Epoque  354
# l'erreur est :  4.61086
# Epoque  355
# l'erreur est :  4.60989
# Epoque  356
# l'erreur est :  4.60894
# Epoque  357
# l'erreur est :  4.60799
# Epoque  358
# l'erreur est :  4.60704
# Epoque  359
# l'erreur est :  4.60611
# Epoque  360
# l'erreur est :  4.60518
# Epoque  361
# l'erreur est :  4.60426
# Epoque  362
# l'erreur est :  4.60334
# Epoque  363
# l'erreur est :  4.60243
# Epoque  364
# l'erreur est :  4.60153
# Epoque  365
# l'erreur est :  4.60063
# Epoque  366
# l'erreur est :  4.59974
# Epoque  367
# l'erreur est :  4.59886
# Epoque  368
# l'erreur est :  4.59798
# Epoque  369
# l'erreur est :  4.59711
# Epoque  370
# l'erreur est :  4.59624
# Epoque  371
# l'erreur est :  4.59539
# Epoque  372
# l'erreur est :  4.59453
# Epoque  373
# l'erreur est :  4.59369
# Epoque  374
# l'erreur est :  4.59285
# Epoque  375
# l'erreur est :  4.59201
# Epoque  376
# l'erreur est :  4.59119
# Epoque  377
# l'erreur est :  4.59036
# Epoque  378
# l'erreur est :  4.58955
# Epoque  379
# l'erreur est :  4.58874
# Epoque  380
# l'erreur est :  4.58793
# Epoque  381
# l'erreur est :  4.58713
# Epoque  382
# l'erreur est :  4.58634
# Epoque  383
# l'erreur est :  4.58555
# Epoque  384
# l'erreur est :  4.58477
# Epoque  385
# l'erreur est :  4.58400
# Epoque  386
# l'erreur est :  4.58323
# Epoque  387
# l'erreur est :  4.58246
# Epoque  388
# l'erreur est :  4.58170
# Epoque  389
# l'erreur est :  4.58095
# Epoque  390
# l'erreur est :  4.58020
# Epoque  391
# l'erreur est :  4.57946
# Epoque  392
# l'erreur est :  4.57872
# Epoque  393
# l'erreur est :  4.57799
# Epoque  394
# l'erreur est :  4.57726
# Epoque  395
# l'erreur est :  4.57654
# Epoque  396
# l'erreur est :  4.57582
# Epoque  397
# l'erreur est :  4.57511
# Epoque  398
# l'erreur est :  4.57440
# Epoque  399
# l'erreur est :  4.57370
# Epoque  400
# l'erreur est :  4.57301
# Epoque  401
# l'erreur est :  4.57232
# Epoque  402
# l'erreur est :  4.57163
# Epoque  403
# l'erreur est :  4.57095
# Epoque  404
# l'erreur est :  4.57027
# Epoque  405
# l'erreur est :  4.56960
# Epoque  406
# l'erreur est :  4.56893
# Epoque  407
# l'erreur est :  4.56827
# Epoque  408
# l'erreur est :  4.56761
# Epoque  409
# l'erreur est :  4.56696
# Epoque  410
# l'erreur est :  4.56631
# Epoque  411
# l'erreur est :  4.56567
# Epoque  412
# l'erreur est :  4.56503
# Epoque  413
# l'erreur est :  4.56440
# Epoque  414
# l'erreur est :  4.56377
# Epoque  415
# l'erreur est :  4.56314
# Epoque  416
# l'erreur est :  4.56252
# Epoque  417
# l'erreur est :  4.56191
# Epoque  418
# l'erreur est :  4.56130
# Epoque  419
# l'erreur est :  4.56069
# Epoque  420
# l'erreur est :  4.56009
# Epoque  421
# l'erreur est :  4.55949
# Epoque  422
# l'erreur est :  4.55890
# Epoque  423
# l'erreur est :  4.55831
# Epoque  424
# l'erreur est :  4.55772
# Epoque  425
# l'erreur est :  4.55714
# Epoque  426
# l'erreur est :  4.55656
# Epoque  427
# l'erreur est :  4.55599
# Epoque  428
# l'erreur est :  4.55542
# Epoque  429
# l'erreur est :  4.55486
# Epoque  430
# l'erreur est :  4.55430
# Epoque  431
# l'erreur est :  4.55374
# Epoque  432
# l'erreur est :  4.55319
# Epoque  433
# l'erreur est :  4.55264
# Epoque  434
# l'erreur est :  4.55209
# Epoque  435
# l'erreur est :  4.55155
# Epoque  436
# l'erreur est :  4.55102
# Epoque  437
# l'erreur est :  4.55048
# Epoque  438
# l'erreur est :  4.54995
# Epoque  439
# l'erreur est :  4.54943
# Epoque  440
# l'erreur est :  4.54891
# Epoque  441
# l'erreur est :  4.54839
# Epoque  442
# l'erreur est :  4.54788
# Epoque  443
# l'erreur est :  4.54737
# Epoque  444
# l'erreur est :  4.54686
# Epoque  445
# l'erreur est :  4.54636
# Epoque  446
# l'erreur est :  4.54586
# Epoque  447
# l'erreur est :  4.54536
# Epoque  448
# l'erreur est :  4.54487
# Epoque  449
# l'erreur est :  4.54438
# Epoque  450
# l'erreur est :  4.54389
# Epoque  451
# l'erreur est :  4.54341
# Epoque  452
# l'erreur est :  4.54293
# Epoque  453
# l'erreur est :  4.54246
# Epoque  454
# l'erreur est :  4.54199
# Epoque  455
# l'erreur est :  4.54152
# Epoque  456
# l'erreur est :  4.54106
# Epoque  457
# l'erreur est :  4.54059
# Epoque  458
# l'erreur est :  4.54014
# Epoque  459
# l'erreur est :  4.53968
# Epoque  460
# l'erreur est :  4.53923
# Epoque  461
# l'erreur est :  4.53878
# Epoque  462
# l'erreur est :  4.53834
# Epoque  463
# l'erreur est :  4.53790
# Epoque  464
# l'erreur est :  4.53746
# Epoque  465
# l'erreur est :  4.53702
# Epoque  466
# l'erreur est :  4.53659
# Epoque  467
# l'erreur est :  4.53616
# Epoque  468
# l'erreur est :  4.53573
# Epoque  469
# l'erreur est :  4.53531
# Epoque  470
# l'erreur est :  4.53489
# Epoque  471
# l'erreur est :  4.53448
# Epoque  472
# l'erreur est :  4.53406
# Epoque  473
# l'erreur est :  4.53365
# Epoque  474
# l'erreur est :  4.53324
# Epoque  475
# l'erreur est :  4.53284
# Epoque  476
# l'erreur est :  4.53244
# Epoque  477
# l'erreur est :  4.53204
# Epoque  478
# l'erreur est :  4.53164
# Epoque  479
# l'erreur est :  4.53125
# Epoque  480
# l'erreur est :  4.53086
# Epoque  481
# l'erreur est :  4.53047
# Epoque  482
# l'erreur est :  4.53008
# Epoque  483
# l'erreur est :  4.52970
# Epoque  484
# l'erreur est :  4.52932
# Epoque  485
# l'erreur est :  4.52894
# Epoque  486
# l'erreur est :  4.52857
# Epoque  487
# l'erreur est :  4.52820
# Epoque  488
# l'erreur est :  4.52783
# Epoque  489
# l'erreur est :  4.52746
# Epoque  490
# l'erreur est :  4.52710
# Epoque  491
# l'erreur est :  4.52674
# Epoque  492
# l'erreur est :  4.52638
# Epoque  493
# l'erreur est :  4.52603
# Epoque  494
# l'erreur est :  4.52567
# Epoque  495
# l'erreur est :  4.52532
# Epoque  496
# l'erreur est :  4.52497
# Epoque  497
# l'erreur est :  4.52463
# Epoque  498
# l'erreur est :  4.52429
# Epoque  499
# l'erreur est :  4.52395
# Epoque  500
# l'erreur est :  4.52361
# Epoque  501
# l'erreur est :  4.52327
# Epoque  502
# l'erreur est :  4.52294
# Epoque  503
# l'erreur est :  4.52261
# Epoque  504
# l'erreur est :  4.52228
# Epoque  505
# l'erreur est :  4.52195
# Epoque  506
# l'erreur est :  4.52163
# Epoque  507
# l'erreur est :  4.52131
# Epoque  508
# l'erreur est :  4.52099
# Epoque  509
# l'erreur est :  4.52067
# Epoque  510
# l'erreur est :  4.52036
# Epoque  511
# l'erreur est :  4.52005
# Epoque  512
# l'erreur est :  4.51974
# Epoque  513
# l'erreur est :  4.51943
# Epoque  514
# l'erreur est :  4.51912
# Epoque  515
# l'erreur est :  4.51882
# Epoque  516
# l'erreur est :  4.51852
# Epoque  517
# l'erreur est :  4.51822
# Epoque  518
# l'erreur est :  4.51792
# Epoque  519
# l'erreur est :  4.51763
# Epoque  520
# l'erreur est :  4.51733
# Epoque  521
# l'erreur est :  4.51704
# Epoque  522
# l'erreur est :  4.51676
# Epoque  523
# l'erreur est :  4.51647
# Epoque  524
# l'erreur est :  4.51618
# Epoque  525
# l'erreur est :  4.51590
# Epoque  526
# l'erreur est :  4.51562
# Epoque  527
# l'erreur est :  4.51534
# Epoque  528
# l'erreur est :  4.51507
# Epoque  529
# l'erreur est :  4.51479
# Epoque  530
# l'erreur est :  4.51452
# Epoque  531
# l'erreur est :  4.51425
# Epoque  532
# l'erreur est :  4.51398
# Epoque  533
# l'erreur est :  4.51372
# Epoque  534
# l'erreur est :  4.51345
# Epoque  535
# l'erreur est :  4.51319
# Epoque  536
# l'erreur est :  4.51293
# Epoque  537
# l'erreur est :  4.51267
# Epoque  538
# l'erreur est :  4.51241
# Epoque  539
# l'erreur est :  4.51216
# Epoque  540
# l'erreur est :  4.51190
# Epoque  541
# l'erreur est :  4.51165
# Epoque  542
# l'erreur est :  4.51140
# Epoque  543
# l'erreur est :  4.51116
# Epoque  544
# l'erreur est :  4.51091
# Epoque  545
# l'erreur est :  4.51067
# Epoque  546
# l'erreur est :  4.51042
# Epoque  547
# l'erreur est :  4.51018
# Epoque  548
# l'erreur est :  4.50994
# Epoque  549
# l'erreur est :  4.50971
# Epoque  550
# l'erreur est :  4.50947
# Epoque  551
# l'erreur est :  4.50924
# Epoque  552
# l'erreur est :  4.50900
# Epoque  553
# l'erreur est :  4.50877
# Epoque  554
# l'erreur est :  4.50854
# Epoque  555
# l'erreur est :  4.50832
# Epoque  556
# l'erreur est :  4.50809
# Epoque  557
# l'erreur est :  4.50787
# Epoque  558
# l'erreur est :  4.50765
# Epoque  559
# l'erreur est :  4.50742
# Epoque  560
# l'erreur est :  4.50721
# Epoque  561
# l'erreur est :  4.50699
# Epoque  562
# l'erreur est :  4.50677
# Epoque  563
# l'erreur est :  4.50656
# Epoque  564
# l'erreur est :  4.50634
# Epoque  565
# l'erreur est :  4.50613
# Epoque  566
# l'erreur est :  4.50592
# Epoque  567
# l'erreur est :  4.50571
# Epoque  568
# l'erreur est :  4.50551
# Epoque  569
# l'erreur est :  4.50530
# Epoque  570
# l'erreur est :  4.50510
# Epoque  571
# l'erreur est :  4.50490
# Epoque  572
# l'erreur est :  4.50470
# Epoque  573
# l'erreur est :  4.50450
# Epoque  574
# l'erreur est :  4.50430
# Epoque  575
# l'erreur est :  4.50410
# Epoque  576
# l'erreur est :  4.50391
# Epoque  577
# l'erreur est :  4.50371
# Epoque  578
# l'erreur est :  4.50352
# Epoque  579
# l'erreur est :  4.50333
# Epoque  580
# l'erreur est :  4.50314
# Epoque  581
# l'erreur est :  4.50295
# Epoque  582
# l'erreur est :  4.50276
# Epoque  583
# l'erreur est :  4.50258
# Epoque  584
# l'erreur est :  4.50239
# Epoque  585
# l'erreur est :  4.50221
# Epoque  586
# l'erreur est :  4.50203
# Epoque  587
# l'erreur est :  4.50185
# Epoque  588
# l'erreur est :  4.50167
# Epoque  589
# l'erreur est :  4.50149
# Epoque  590
# l'erreur est :  4.50131
# Epoque  591
# l'erreur est :  4.50114
# Epoque  592
# l'erreur est :  4.50097
# Epoque  593
# l'erreur est :  4.50079
# Epoque  594
# l'erreur est :  4.50062
# Epoque  595
# l'erreur est :  4.50045
# Epoque  596
# l'erreur est :  4.50028
# Epoque  597
# l'erreur est :  4.50011
# Epoque  598
# l'erreur est :  4.49995
# Epoque  599
# l'erreur est :  4.49978
# Epoque  600
# l'erreur est :  4.49962
# Epoque  601
# l'erreur est :  4.49946
# Epoque  602
# l'erreur est :  4.49929
# Epoque  603
# l'erreur est :  4.49913
# Epoque  604
# l'erreur est :  4.49897
# Epoque  605
# l'erreur est :  4.49882
# Epoque  606
# l'erreur est :  4.49866
# Epoque  607
# l'erreur est :  4.49850
# Epoque  608
# l'erreur est :  4.49835
# Epoque  609
# l'erreur est :  4.49819
# Epoque  610
# l'erreur est :  4.49804
# Epoque  611
# l'erreur est :  4.49789
# Epoque  612
# l'erreur est :  4.49774
# Epoque  613
# l'erreur est :  4.49759
# Epoque  614
# l'erreur est :  4.49744
# Epoque  615
# l'erreur est :  4.49729
# Epoque  616
# l'erreur est :  4.49715
# Epoque  617
# l'erreur est :  4.49700
# Epoque  618
# l'erreur est :  4.49686
# Epoque  619
# l'erreur est :  4.49671
# Epoque  620
# l'erreur est :  4.49657
# Epoque  621
# l'erreur est :  4.49643
# Epoque  622
# l'erreur est :  4.49629
# Epoque  623
# l'erreur est :  4.49615
# Epoque  624
# l'erreur est :  4.49601
# Epoque  625
# l'erreur est :  4.49588
# Epoque  626
# l'erreur est :  4.49574
# Epoque  627
# l'erreur est :  4.49561
# Epoque  628
# l'erreur est :  4.49547
# Epoque  629
# l'erreur est :  4.49534
# Epoque  630
# l'erreur est :  4.49521
# Epoque  631
# l'erreur est :  4.49507
# Epoque  632
# l'erreur est :  4.49494
# Epoque  633
# l'erreur est :  4.49482
# Epoque  634
# l'erreur est :  4.49469
# Epoque  635
# l'erreur est :  4.49456
# Epoque  636
# l'erreur est :  4.49443
# Epoque  637
# l'erreur est :  4.49431
# Epoque  638
# l'erreur est :  4.49418
# Epoque  639
# l'erreur est :  4.49406
# Epoque  640
# l'erreur est :  4.49394
# Epoque  641
# l'erreur est :  4.49381
# Epoque  642
# l'erreur est :  4.49369
# Epoque  643
# l'erreur est :  4.49357
# Epoque  644
# l'erreur est :  4.49345
# Epoque  645
# l'erreur est :  4.49333
# Epoque  646
# l'erreur est :  4.49322
# Epoque  647
# l'erreur est :  4.49310
# Epoque  648
# l'erreur est :  4.49298
# Epoque  649
# l'erreur est :  4.49287
# Epoque  650
# l'erreur est :  4.49275
# Epoque  651
# l'erreur est :  4.49264
# Epoque  652
# l'erreur est :  4.49253
# Epoque  653
# l'erreur est :  4.49241
# Epoque  654
# l'erreur est :  4.49230
# Epoque  655
# l'erreur est :  4.49219
# Epoque  656
# l'erreur est :  4.49208
# Epoque  657
# l'erreur est :  4.49198
# Epoque  658
# l'erreur est :  4.49187
# Epoque  659
# l'erreur est :  4.49176
# Epoque  660
# l'erreur est :  4.49165
# Epoque  661
# l'erreur est :  4.49155
# Epoque  662
# l'erreur est :  4.49144
# Epoque  663
# l'erreur est :  4.49134
# Epoque  664
# l'erreur est :  4.49124
# Epoque  665
# l'erreur est :  4.49113
# Epoque  666
# l'erreur est :  4.49103
# Epoque  667
# l'erreur est :  4.49093
# Epoque  668
# l'erreur est :  4.49083
# Epoque  669
# l'erreur est :  4.49073
# Epoque  670
# l'erreur est :  4.49063
# Epoque  671
# l'erreur est :  4.49053
# Epoque  672
# l'erreur est :  4.49043
# Epoque  673
# l'erreur est :  4.49034
# Epoque  674
# l'erreur est :  4.49024
# Epoque  675
# l'erreur est :  4.49015
# Epoque  676
# l'erreur est :  4.49005
# Epoque  677
# l'erreur est :  4.48996
# Epoque  678
# l'erreur est :  4.48986
# Epoque  679
# l'erreur est :  4.48977
# Epoque  680
# l'erreur est :  4.48968
# Epoque  681
# l'erreur est :  4.48959
# Epoque  682
# l'erreur est :  4.48950
# Epoque  683
# l'erreur est :  4.48941
# Epoque  684
# l'erreur est :  4.48932
# Epoque  685
# l'erreur est :  4.48923
# Epoque  686
# l'erreur est :  4.48914
# Epoque  687
# l'erreur est :  4.48905
# Epoque  688
# l'erreur est :  4.48896
# Epoque  689
# l'erreur est :  4.48888
# Epoque  690
# l'erreur est :  4.48879
# Epoque  691
# l'erreur est :  4.48871
# Epoque  692
# l'erreur est :  4.48862
# Epoque  693
# l'erreur est :  4.48854
# Epoque  694
# l'erreur est :  4.48846
# Epoque  695
# l'erreur est :  4.48837
# Epoque  696
# l'erreur est :  4.48829
# Epoque  697
# l'erreur est :  4.48821
# Epoque  698
# l'erreur est :  4.48813
# Epoque  699
# l'erreur est :  4.48805
# Epoque  700
# l'erreur est :  4.48797
# Epoque  701
# l'erreur est :  4.48789
# Epoque  702
# l'erreur est :  4.48781
# Epoque  703
# l'erreur est :  4.48773
# Epoque  704
# l'erreur est :  4.48766
# Epoque  705
# l'erreur est :  4.48758
# Epoque  706
# l'erreur est :  4.48750
# Epoque  707
# l'erreur est :  4.48743
# Epoque  708
# l'erreur est :  4.48735
# Epoque  709
# l'erreur est :  4.48728
# Epoque  710
# l'erreur est :  4.48720
# Epoque  711
# l'erreur est :  4.48713
# Epoque  712
# l'erreur est :  4.48706
# Epoque  713
# l'erreur est :  4.48698
# Epoque  714
# l'erreur est :  4.48691
# Epoque  715
# l'erreur est :  4.48684
# Epoque  716
# l'erreur est :  4.48677
# Epoque  717
# l'erreur est :  4.48670
# Epoque  718
# l'erreur est :  4.48663
# Epoque  719
# l'erreur est :  4.48656
# Epoque  720
# l'erreur est :  4.48649
# Epoque  721
# l'erreur est :  4.48642
# Epoque  722
# l'erreur est :  4.48635
# Epoque  723
# l'erreur est :  4.48629
# Epoque  724
# l'erreur est :  4.48622
# Epoque  725
# l'erreur est :  4.48615
# Epoque  726
# l'erreur est :  4.48609
# Epoque  727
# l'erreur est :  4.48602
# Epoque  728
# l'erreur est :  4.48596
# Epoque  729
# l'erreur est :  4.48589
# Epoque  730
# l'erreur est :  4.48583
# Epoque  731
# l'erreur est :  4.48576
# Epoque  732
# l'erreur est :  4.48570
# Epoque  733
# l'erreur est :  4.48564
# Epoque  734
# l'erreur est :  4.48557
# Epoque  735
# l'erreur est :  4.48551
# Epoque  736
# l'erreur est :  4.48545
# Epoque  737
# l'erreur est :  4.48539
# Epoque  738
# l'erreur est :  4.48533
# Epoque  739
# l'erreur est :  4.48527
# Epoque  740
# l'erreur est :  4.48521
# Epoque  741
# l'erreur est :  4.48515
# Epoque  742
# l'erreur est :  4.48509
# Epoque  743
# l'erreur est :  4.48503
# Epoque  744
# l'erreur est :  4.48497
# Epoque  745
# l'erreur est :  4.48492
# Epoque  746
# l'erreur est :  4.48486
# Epoque  747
# l'erreur est :  4.48480
# Epoque  748
# l'erreur est :  4.48475
# Epoque  749
# l'erreur est :  4.48469
# Epoque  750
# l'erreur est :  4.48464
# Epoque  751
# l'erreur est :  4.48458
# Epoque  752
# l'erreur est :  4.48453
# Epoque  753
# l'erreur est :  4.48447
# Epoque  754
# l'erreur est :  4.48442
# Epoque  755
# l'erreur est :  4.48436
# Epoque  756
# l'erreur est :  4.48431
# Epoque  757
# l'erreur est :  4.48426
# Epoque  758
# l'erreur est :  4.48420
# Epoque  759
# l'erreur est :  4.48415
# Epoque  760
# l'erreur est :  4.48410
# Epoque  761
# l'erreur est :  4.48405
# Epoque  762
# l'erreur est :  4.48400
# Epoque  763
# l'erreur est :  4.48395
# Epoque  764
# l'erreur est :  4.48390
# Epoque  765
# l'erreur est :  4.48385
# Epoque  766
# l'erreur est :  4.48380
# Epoque  767
# l'erreur est :  4.48375
# Epoque  768
# l'erreur est :  4.48370
# Epoque  769
# l'erreur est :  4.48365
# Epoque  770
# l'erreur est :  4.48360
# Epoque  771
# l'erreur est :  4.48356
# Epoque  772
# l'erreur est :  4.48351
# Epoque  773
# l'erreur est :  4.48346
# Epoque  774
# l'erreur est :  4.48342
# Epoque  775
# l'erreur est :  4.48337
# Epoque  776
# l'erreur est :  4.48332
# Epoque  777
# l'erreur est :  4.48328
# Epoque  778
# l'erreur est :  4.48323
# Epoque  779
# l'erreur est :  4.48319
# Epoque  780
# l'erreur est :  4.48314
# Epoque  781
# l'erreur est :  4.48310
# Epoque  782
# l'erreur est :  4.48305
# Epoque  783
# l'erreur est :  4.48301
# Epoque  784
# l'erreur est :  4.48297
# Epoque  785
# l'erreur est :  4.48292
# Epoque  786
# l'erreur est :  4.48288
# Epoque  787
# l'erreur est :  4.48284
# Epoque  788
# l'erreur est :  4.48280
# Epoque  789
# l'erreur est :  4.48275
# Epoque  790
# l'erreur est :  4.48271
# Epoque  791
# l'erreur est :  4.48267
# Epoque  792
# l'erreur est :  4.48263
# Epoque  793
# l'erreur est :  4.48259
# Epoque  794
# l'erreur est :  4.48255
# Epoque  795
# l'erreur est :  4.48251
# Epoque  796
# l'erreur est :  4.48247
# Epoque  797
# l'erreur est :  4.48243
# Epoque  798
# l'erreur est :  4.48239
# Epoque  799
# l'erreur est :  4.48235
# Epoque  800
# l'erreur est :  4.48231
# Epoque  801
# l'erreur est :  4.48227
# Epoque  802
# l'erreur est :  4.48224
# Epoque  803
# l'erreur est :  4.48220
# Epoque  804
# l'erreur est :  4.48216
# Epoque  805
# l'erreur est :  4.48212
# Epoque  806
# l'erreur est :  4.48209
# Epoque  807
# l'erreur est :  4.48205
# Epoque  808
# l'erreur est :  4.48201
# Epoque  809
# l'erreur est :  4.48198
# Epoque  810
# l'erreur est :  4.48194
# Epoque  811
# l'erreur est :  4.48190
# Epoque  812
# l'erreur est :  4.48187
# Epoque  813
# l'erreur est :  4.48183
# Epoque  814
# l'erreur est :  4.48180
# Epoque  815
# l'erreur est :  4.48176
# Epoque  816
# l'erreur est :  4.48173
# Epoque  817
# l'erreur est :  4.48169
# Epoque  818
# l'erreur est :  4.48166
# Epoque  819
# l'erreur est :  4.48163
# Epoque  820
# l'erreur est :  4.48159
# Epoque  821
# l'erreur est :  4.48156
# Epoque  822
# l'erreur est :  4.48153
# Epoque  823
# l'erreur est :  4.48149
# Epoque  824
# l'erreur est :  4.48146
# Epoque  825
# l'erreur est :  4.48143
# Epoque  826
# l'erreur est :  4.48140
# Epoque  827
# l'erreur est :  4.48137
# Epoque  828
# l'erreur est :  4.48133
# Epoque  829
# l'erreur est :  4.48130
# Epoque  830
# l'erreur est :  4.48127
# Epoque  831
# l'erreur est :  4.48124
# Epoque  832
# l'erreur est :  4.48121
# Epoque  833
# l'erreur est :  4.48118
# Epoque  834
# l'erreur est :  4.48115
# Epoque  835
# l'erreur est :  4.48112
# Epoque  836
# l'erreur est :  4.48109
# Epoque  837
# l'erreur est :  4.48106
# Epoque  838
# l'erreur est :  4.48103
# Epoque  839
# l'erreur est :  4.48100
# Epoque  840
# l'erreur est :  4.48097
# Epoque  841
# l'erreur est :  4.48094
# Epoque  842
# l'erreur est :  4.48091
# Epoque  843
# l'erreur est :  4.48089
# Epoque  844
# l'erreur est :  4.48086
# Epoque  845
# l'erreur est :  4.48083
# Epoque  846
# l'erreur est :  4.48080
# Epoque  847
# l'erreur est :  4.48077
# Epoque  848
# l'erreur est :  4.48075
# Epoque  849
# l'erreur est :  4.48072
# Epoque  850
# l'erreur est :  4.48069
# Epoque  851
# l'erreur est :  4.48067
# Epoque  852
# l'erreur est :  4.48064
# Epoque  853
# l'erreur est :  4.48061
# Epoque  854
# l'erreur est :  4.48059
# Epoque  855
# l'erreur est :  4.48056
# Epoque  856
# l'erreur est :  4.48054
# Epoque  857
# l'erreur est :  4.48051
# Epoque  858
# l'erreur est :  4.48048
# Epoque  859
# l'erreur est :  4.48046
# Epoque  860
# l'erreur est :  4.48043
# Epoque  861
# l'erreur est :  4.48041
# Epoque  862
# l'erreur est :  4.48038
# Epoque  863
# l'erreur est :  4.48036
# Epoque  864
# l'erreur est :  4.48034
# Epoque  865
# l'erreur est :  4.48031
# Epoque  866
# l'erreur est :  4.48029
# Epoque  867
# l'erreur est :  4.48026
# Epoque  868
# l'erreur est :  4.48024
# Epoque  869
# l'erreur est :  4.48022
# Epoque  870
# l'erreur est :  4.48019
# Epoque  871
# l'erreur est :  4.48017
# Epoque  872
# l'erreur est :  4.48015
# Epoque  873
# l'erreur est :  4.48012
# Epoque  874
# l'erreur est :  4.48010
# Epoque  875
# l'erreur est :  4.48008
# Epoque  876
# l'erreur est :  4.48006
# Epoque  877
# l'erreur est :  4.48003
# Epoque  878
# l'erreur est :  4.48001
# Epoque  879
# l'erreur est :  4.47999
# Epoque  880
# l'erreur est :  4.47997
# Epoque  881
# l'erreur est :  4.47995
# Epoque  882
# l'erreur est :  4.47992
# Epoque  883
# l'erreur est :  4.47990
# Epoque  884
# l'erreur est :  4.47988
# Epoque  885
# l'erreur est :  4.47986
# Epoque  886
# l'erreur est :  4.47984
# Epoque  887
# l'erreur est :  4.47982
# Epoque  888
# l'erreur est :  4.47980
# Epoque  889
# l'erreur est :  4.47978
# Epoque  890
# l'erreur est :  4.47976
# Epoque  891
# l'erreur est :  4.47974
# Epoque  892
# l'erreur est :  4.47972
# Epoque  893
# l'erreur est :  4.47970
# Epoque  894
# l'erreur est :  4.47968
# Epoque  895
# l'erreur est :  4.47966
# Epoque  896
# l'erreur est :  4.47964
# Epoque  897
# l'erreur est :  4.47962
# Epoque  898
# l'erreur est :  4.47960
# Epoque  899
# l'erreur est :  4.47958
# Epoque  900
# l'erreur est :  4.47956
# Epoque  901
# l'erreur est :  4.47955
# Epoque  902
# l'erreur est :  4.47953
# Epoque  903
# l'erreur est :  4.47951
# Epoque  904
# l'erreur est :  4.47949
# Epoque  905
# l'erreur est :  4.47947
# Epoque  906
# l'erreur est :  4.47945
# Epoque  907
# l'erreur est :  4.47944
# Epoque  908
# l'erreur est :  4.47942
# Epoque  909
# l'erreur est :  4.47940
# Epoque  910
# l'erreur est :  4.47938
# Epoque  911
# l'erreur est :  4.47937
# Epoque  912
# l'erreur est :  4.47935
# Epoque  913
# l'erreur est :  4.47933
# Epoque  914
# l'erreur est :  4.47932
# Epoque  915
# l'erreur est :  4.47930
# Epoque  916
# l'erreur est :  4.47928
# Epoque  917
# l'erreur est :  4.47927
# Epoque  918
# l'erreur est :  4.47925
# Epoque  919
# l'erreur est :  4.47923
# Epoque  920
# l'erreur est :  4.47922
# Epoque  921
# l'erreur est :  4.47920
# Epoque  922
# l'erreur est :  4.47918
# Epoque  923
# l'erreur est :  4.47917
# Epoque  924
# l'erreur est :  4.47915
# Epoque  925
# l'erreur est :  4.47914
# Epoque  926
# l'erreur est :  4.47912
# Epoque  927
# l'erreur est :  4.47911
# Epoque  928
# l'erreur est :  4.47909
# Epoque  929
# l'erreur est :  4.47907
# Epoque  930
# l'erreur est :  4.47906
# Epoque  931
# l'erreur est :  4.47904
# Epoque  932
# l'erreur est :  4.47903
# Epoque  933
# l'erreur est :  4.47901
# Epoque  934
# l'erreur est :  4.47900
# Epoque  935
# l'erreur est :  4.47899
# Epoque  936
# l'erreur est :  4.47897
# Epoque  937
# l'erreur est :  4.47896
# Epoque  938
# l'erreur est :  4.47894
# Epoque  939
# l'erreur est :  4.47893
# Epoque  940
# l'erreur est :  4.47891
# Epoque  941
# l'erreur est :  4.47890
# Epoque  942
# l'erreur est :  4.47889
# Epoque  943
# l'erreur est :  4.47887
# Epoque  944
# l'erreur est :  4.47886
# Epoque  945
# l'erreur est :  4.47885
# Epoque  946
# l'erreur est :  4.47883
# Epoque  947
# l'erreur est :  4.47882
# Epoque  948
# l'erreur est :  4.47880
# Epoque  949
# l'erreur est :  4.47879
# Epoque  950
# l'erreur est :  4.47878
# Epoque  951
# l'erreur est :  4.47877
# Epoque  952
# l'erreur est :  4.47875
# Epoque  953
# l'erreur est :  4.47874
# Epoque  954
# l'erreur est :  4.47873
# Epoque  955
# l'erreur est :  4.47871
# Epoque  956
# l'erreur est :  4.47870
# Epoque  957
# l'erreur est :  4.47869
# Epoque  958
# l'erreur est :  4.47868
# Epoque  959
# l'erreur est :  4.47866
# Epoque  960
# l'erreur est :  4.47865
# Epoque  961
# l'erreur est :  4.47864
# Epoque  962
# l'erreur est :  4.47863
# Epoque  963
# l'erreur est :  4.47862
# Epoque  964
# l'erreur est :  4.47860
# Epoque  965
# l'erreur est :  4.47859
# Epoque  966
# l'erreur est :  4.47858
# Epoque  967
# l'erreur est :  4.47857
# Epoque  968
# l'erreur est :  4.47856
# Epoque  969
# l'erreur est :  4.47855
# Epoque  970
# l'erreur est :  4.47854
# Epoque  971
# l'erreur est :  4.47852
# Epoque  972
# l'erreur est :  4.47851
# Epoque  973
# l'erreur est :  4.47850
# Epoque  974
# l'erreur est :  4.47849
# Epoque  975
# l'erreur est :  4.47848
# Epoque  976
# l'erreur est :  4.47847
# Epoque  977
# l'erreur est :  4.47846
# Epoque  978
# l'erreur est :  4.47845
# Epoque  979
# l'erreur est :  4.47844
# Epoque  980
# l'erreur est :  4.47843
# Epoque  981
# l'erreur est :  4.47842
# Epoque  982
# l'erreur est :  4.47841
# Epoque  983
# l'erreur est :  4.47840
# Epoque  984
# l'erreur est :  4.47839
# Epoque  985
# l'erreur est :  4.47837
# Epoque  986
# l'erreur est :  4.47836
# Epoque  987
# l'erreur est :  4.47835
# Epoque  988
# l'erreur est :  4.47834
# Epoque  989
# l'erreur est :  4.47833
# Epoque  990
# l'erreur est :  4.47833
# Epoque  991
# l'erreur est :  4.47832
# Epoque  992
# l'erreur est :  4.47831
# Epoque  993
# l'erreur est :  4.47830
# Epoque  994
# l'erreur est :  4.47829
# Epoque  995
# l'erreur est :  4.47828
# Epoque  996
# l'erreur est :  4.47827
# Epoque  997
# l'erreur est :  4.47826
# Epoque  998
# l'erreur est :  4.47825
# Epoque  999
# l'erreur est :  4.47824
# Epoque  1000
# l'erreur est :  4.47823
# Epoque  1001
# l'erreur est :  4.47822
# Epoque  1002
# l'erreur est :  4.47821
# Epoque  1003
# l'erreur est :  4.47820
# Epoque  1004
# l'erreur est :  4.47819
# Epoque  1005
# l'erreur est :  4.47819
# Epoque  1006
# l'erreur est :  4.47818
# Epoque  1007
# l'erreur est :  4.47817
# Epoque  1008
# l'erreur est :  4.47816
# Epoque  1009
# l'erreur est :  4.47815
# Epoque  1010
# l'erreur est :  4.47814
# Epoque  1011
# l'erreur est :  4.47813
# Epoque  1012
# l'erreur est :  4.47813
# Epoque  1013
# l'erreur est :  4.47812
# Epoque  1014
# l'erreur est :  4.47811
# Epoque  1015
# l'erreur est :  4.47810
# Epoque  1016
# l'erreur est :  4.47809
# Epoque  1017
# l'erreur est :  4.47809
# Epoque  1018
# l'erreur est :  4.47808
# Epoque  1019
# l'erreur est :  4.47807
# Epoque  1020
# l'erreur est :  4.47806
# Epoque  1021
# l'erreur est :  4.47805
# Epoque  1022
# l'erreur est :  4.47805
# Epoque  1023
# l'erreur est :  4.47804
# Epoque  1024
# l'erreur est :  4.47803
# Epoque  1025
# l'erreur est :  4.47802
# Epoque  1026
# l'erreur est :  4.47802
# Epoque  1027
# l'erreur est :  4.47801
# Epoque  1028
# l'erreur est :  4.47800
# Epoque  1029
# l'erreur est :  4.47799
# Epoque  1030
# l'erreur est :  4.47799
# Epoque  1031
# l'erreur est :  4.47798
# Epoque  1032
# l'erreur est :  4.47797
# Epoque  1033
# l'erreur est :  4.47796
# Epoque  1034
# l'erreur est :  4.47796
# Epoque  1035
# l'erreur est :  4.47795
# Epoque  1036
# l'erreur est :  4.47794
# Epoque  1037
# l'erreur est :  4.47794
# Epoque  1038
# l'erreur est :  4.47793
# Epoque  1039
# l'erreur est :  4.47792
# Epoque  1040
# l'erreur est :  4.47791
# Epoque  1041
# l'erreur est :  4.47791
# Epoque  1042
# l'erreur est :  4.47790
# Epoque  1043
# l'erreur est :  4.47789
# Epoque  1044
# l'erreur est :  4.47789
# Epoque  1045
# l'erreur est :  4.47788
# Epoque  1046
# l'erreur est :  4.47787
# Epoque  1047
# l'erreur est :  4.47787
# Epoque  1048
# l'erreur est :  4.47786
# Epoque  1049
# l'erreur est :  4.47786
# Epoque  1050
# l'erreur est :  4.47785
# Epoque  1051
# l'erreur est :  4.47784
# Epoque  1052
# l'erreur est :  4.47784
# Epoque  1053
# l'erreur est :  4.47783
# Epoque  1054
# l'erreur est :  4.47782
# Epoque  1055
# l'erreur est :  4.47782
# Epoque  1056
# l'erreur est :  4.47781
# Epoque  1057
# l'erreur est :  4.47781
# Epoque  1058
# l'erreur est :  4.47780
# Epoque  1059
# l'erreur est :  4.47779
# Epoque  1060
# l'erreur est :  4.47779
# Epoque  1061
# l'erreur est :  4.47778
# Epoque  1062
# l'erreur est :  4.47778
# Epoque  1063
# l'erreur est :  4.47777
# Epoque  1064
# l'erreur est :  4.47776
# Epoque  1065
# l'erreur est :  4.47776
# Epoque  1066
# l'erreur est :  4.47775
# Epoque  1067
# l'erreur est :  4.47775
# Epoque  1068
# l'erreur est :  4.47774
# Epoque  1069
# l'erreur est :  4.47774
# Epoque  1070
# l'erreur est :  4.47773
# Epoque  1071
# l'erreur est :  4.47773
# Epoque  1072
# l'erreur est :  4.47772
# Epoque  1073
# l'erreur est :  4.47771
# Epoque  1074
# l'erreur est :  4.47771
# Epoque  1075
# l'erreur est :  4.47770
# Epoque  1076
# l'erreur est :  4.47770
# Epoque  1077
# l'erreur est :  4.47769
# Epoque  1078
# l'erreur est :  4.47769
# Epoque  1079
# l'erreur est :  4.47768
# Epoque  1080
# l'erreur est :  4.47768
# Epoque  1081
# l'erreur est :  4.47767
# Epoque  1082
# l'erreur est :  4.47767
# Epoque  1083
# l'erreur est :  4.47766
# Epoque  1084
# l'erreur est :  4.47766
# Epoque  1085
# l'erreur est :  4.47765
# Epoque  1086
# l'erreur est :  4.47765
# Epoque  1087
# l'erreur est :  4.47764
# Epoque  1088
# l'erreur est :  4.47764
# Epoque  1089
# l'erreur est :  4.47763
# Epoque  1090
# l'erreur est :  4.47763
# Epoque  1091
# l'erreur est :  4.47762
# Epoque  1092
# l'erreur est :  4.47762
# Epoque  1093
# l'erreur est :  4.47761
# Epoque  1094
# l'erreur est :  4.47761
# Epoque  1095
# l'erreur est :  4.47761
# Epoque  1096
# l'erreur est :  4.47760
# Epoque  1097
# l'erreur est :  4.47760
# Epoque  1098
# l'erreur est :  4.47759
# Epoque  1099
# l'erreur est :  4.47759
# Epoque  1100
# l'erreur est :  4.47758
# Epoque  1101
# l'erreur est :  4.47758
# Epoque  1102
# l'erreur est :  4.47757
# Epoque  1103
# l'erreur est :  4.47757
# Epoque  1104
# l'erreur est :  4.47757
# Epoque  1105
# l'erreur est :  4.47756
# Epoque  1106
# l'erreur est :  4.47756
# Epoque  1107
# l'erreur est :  4.47755
# Epoque  1108
# l'erreur est :  4.47755
# Epoque  1109
# l'erreur est :  4.47754
# Epoque  1110
# l'erreur est :  4.47754
# Epoque  1111
# l'erreur est :  4.47754
# Epoque  1112
# l'erreur est :  4.47753
# Epoque  1113
# l'erreur est :  4.47753
# Epoque  1114
# l'erreur est :  4.47752
# Epoque  1115
# l'erreur est :  4.47752
# Epoque  1116
# l'erreur est :  4.47752
# Epoque  1117
# l'erreur est :  4.47751
# Epoque  1118
# l'erreur est :  4.47751
# Epoque  1119
# l'erreur est :  4.47750
# Epoque  1120
# l'erreur est :  4.47750
# Epoque  1121
# l'erreur est :  4.47750
# Epoque  1122
# l'erreur est :  4.47749
# Epoque  1123
# l'erreur est :  4.47749
# Epoque  1124
# l'erreur est :  4.47749
# Epoque  1125
# l'erreur est :  4.47748
# Epoque  1126
# l'erreur est :  4.47748
# Epoque  1127
# l'erreur est :  4.47747
# Epoque  1128
# l'erreur est :  4.47747
# Epoque  1129
# l'erreur est :  4.47747
# Epoque  1130
# l'erreur est :  4.47746
# Epoque  1131
# l'erreur est :  4.47746
# Epoque  1132
# l'erreur est :  4.47746
# Epoque  1133
# l'erreur est :  4.47745
# Epoque  1134
# l'erreur est :  4.47745
# Epoque  1135
# l'erreur est :  4.47745
# Epoque  1136
# l'erreur est :  4.47744
# Epoque  1137
# l'erreur est :  4.47744
# Epoque  1138
# l'erreur est :  4.47744
# Epoque  1139
# l'erreur est :  4.47743
# Epoque  1140
# l'erreur est :  4.47743
# Epoque  1141
# l'erreur est :  4.47743
# Epoque  1142
# l'erreur est :  4.47742
# Epoque  1143
# l'erreur est :  4.47742
# Epoque  1144
# l'erreur est :  4.47742
# Epoque  1145
# l'erreur est :  4.47741
# Epoque  1146
# l'erreur est :  4.47741
# Epoque  1147
# l'erreur est :  4.47741
# Epoque  1148
# l'erreur est :  4.47740
# Epoque  1149
# l'erreur est :  4.47740
# Epoque  1150
# l'erreur est :  4.47740
# Epoque  1151
# l'erreur est :  4.47739
# Epoque  1152
# l'erreur est :  4.47739
# Epoque  1153
# l'erreur est :  4.47739
# Epoque  1154
# l'erreur est :  4.47739
# Epoque  1155
# l'erreur est :  4.47738
# Epoque  1156
# l'erreur est :  4.47738
# Epoque  1157
# l'erreur est :  4.47738
# Epoque  1158
# l'erreur est :  4.47737
# Epoque  1159
# l'erreur est :  4.47737
# Epoque  1160
# l'erreur est :  4.47737
# Epoque  1161
# l'erreur est :  4.47737
# Epoque  1162
# l'erreur est :  4.47736
# Epoque  1163
# l'erreur est :  4.47736
# Epoque  1164
# l'erreur est :  4.47736
# Epoque  1165
# l'erreur est :  4.47735
# Epoque  1166
# l'erreur est :  4.47735
# Epoque  1167
# l'erreur est :  4.47735
# Epoque  1168
# l'erreur est :  4.47735
# Epoque  1169
# l'erreur est :  4.47734
# Epoque  1170
# l'erreur est :  4.47734
# Epoque  1171
# l'erreur est :  4.47734
# Epoque  1172
# l'erreur est :  4.47733
# Epoque  1173
# l'erreur est :  4.47733
# Epoque  1174
# l'erreur est :  4.47733
# Epoque  1175
# l'erreur est :  4.47733
# Epoque  1176
# l'erreur est :  4.47732
# Epoque  1177
# l'erreur est :  4.47732
# Epoque  1178
# l'erreur est :  4.47732
# Epoque  1179
# l'erreur est :  4.47732
# Epoque  1180
# l'erreur est :  4.47731
# Epoque  1181
# l'erreur est :  4.47731
# Epoque  1182
# l'erreur est :  4.47731
# Epoque  1183
# l'erreur est :  4.47731
# Epoque  1184
# l'erreur est :  4.47730
# Epoque  1185
# l'erreur est :  4.47730
# Epoque  1186
# l'erreur est :  4.47730
# Epoque  1187
# l'erreur est :  4.47730
# Epoque  1188
# l'erreur est :  4.47730
# Epoque  1189
# l'erreur est :  4.47729
# Epoque  1190
# l'erreur est :  4.47729
# Epoque  1191
# l'erreur est :  4.47729
# Epoque  1192
# l'erreur est :  4.47729
# Epoque  1193
# l'erreur est :  4.47728
# Epoque  1194
# l'erreur est :  4.47728
# Epoque  1195
# l'erreur est :  4.47728
# Epoque  1196
# l'erreur est :  4.47728
# Epoque  1197
# l'erreur est :  4.47727
# Epoque  1198
# l'erreur est :  4.47727
# Epoque  1199
# l'erreur est :  4.47727
# Epoque  1200
# l'erreur est :  4.47727
# Epoque  1201
# l'erreur est :  4.47727
# Epoque  1202
# l'erreur est :  4.47726
# Epoque  1203
# l'erreur est :  4.47726
# Epoque  1204
# l'erreur est :  4.47726
# Epoque  1205
# l'erreur est :  4.47726
# Epoque  1206
# l'erreur est :  4.47726
# Epoque  1207
# l'erreur est :  4.47725
# Epoque  1208
# l'erreur est :  4.47725
# Epoque  1209
# l'erreur est :  4.47725
# Epoque  1210
# l'erreur est :  4.47725
# Epoque  1211
# l'erreur est :  4.47725
# Epoque  1212
# l'erreur est :  4.47724
# Epoque  1213
# l'erreur est :  4.47724
# Epoque  1214
# l'erreur est :  4.47724
# Epoque  1215
# l'erreur est :  4.47724
# Epoque  1216
# l'erreur est :  4.47724
# Epoque  1217
# l'erreur est :  4.47723
# Epoque  1218
# l'erreur est :  4.47723
# Epoque  1219
# l'erreur est :  4.47723
# Epoque  1220
# l'erreur est :  4.47723
# Epoque  1221
# l'erreur est :  4.47723
# Epoque  1222
# l'erreur est :  4.47722
# Epoque  1223
# l'erreur est :  4.47722
# Epoque  1224
# l'erreur est :  4.47722
# Epoque  1225
# l'erreur est :  4.47722
# Epoque  1226
# l'erreur est :  4.47722
# Epoque  1227
# l'erreur est :  4.47722
# Epoque  1228
# l'erreur est :  4.47721
# Epoque  1229
# l'erreur est :  4.47721
# Epoque  1230
# l'erreur est :  4.47721
# Epoque  1231
# l'erreur est :  4.47721
# Epoque  1232
# l'erreur est :  4.47721
# Epoque  1233
# l'erreur est :  4.47721
# Epoque  1234
# l'erreur est :  4.47720
# Epoque  1235
# l'erreur est :  4.47720
# Epoque  1236
# l'erreur est :  4.47720
# Epoque  1237
# l'erreur est :  4.47720
# Epoque  1238
# l'erreur est :  4.47720
# Epoque  1239
# l'erreur est :  4.47720
# Epoque  1240
# l'erreur est :  4.47719
# Epoque  1241
# l'erreur est :  4.47719
# Epoque  1242
# l'erreur est :  4.47719
# Epoque  1243
# l'erreur est :  4.47719
# Epoque  1244
# l'erreur est :  4.47719
# Epoque  1245
# l'erreur est :  4.47719
# Epoque  1246
# l'erreur est :  4.47718
# Epoque  1247
# l'erreur est :  4.47718
# Epoque  1248
# l'erreur est :  4.47718
# Epoque  1249
# l'erreur est :  4.47718
# Epoque  1250
# l'erreur est :  4.47718
# Epoque  1251
# l'erreur est :  4.47718
# Epoque  1252
# l'erreur est :  4.47718
# Epoque  1253
# l'erreur est :  4.47717
# Epoque  1254
# l'erreur est :  4.47717
# Epoque  1255
# l'erreur est :  4.47717
# Epoque  1256
# l'erreur est :  4.47717
# Epoque  1257
# l'erreur est :  4.47717
# Epoque  1258
# l'erreur est :  4.47717
# Epoque  1259
# l'erreur est :  4.47717
# Epoque  1260
# l'erreur est :  4.47716
# Epoque  1261
# l'erreur est :  4.47716
# Epoque  1262
# l'erreur est :  4.47716
# Epoque  1263
# l'erreur est :  4.47716
# Epoque  1264
# l'erreur est :  4.47716
# Epoque  1265
# l'erreur est :  4.47716
# Epoque  1266
# l'erreur est :  4.47716
# Epoque  1267
# l'erreur est :  4.47715
# Epoque  1268
# l'erreur est :  4.47715
# Epoque  1269
# l'erreur est :  4.47715
# Epoque  1270
# l'erreur est :  4.47715
# Epoque  1271
# l'erreur est :  4.47715
# Epoque  1272
# l'erreur est :  4.47715
# Epoque  1273
# l'erreur est :  4.47715
# Epoque  1274
# l'erreur est :  4.47715
# Epoque  1275
# l'erreur est :  4.47714
# Epoque  1276
# l'erreur est :  4.47714
# Epoque  1277
# l'erreur est :  4.47714
# Epoque  1278
# l'erreur est :  4.47714
# Epoque  1279
# l'erreur est :  4.47714
# Epoque  1280
# l'erreur est :  4.47714
# Epoque  1281
# l'erreur est :  4.47714
# Epoque  1282
# l'erreur est :  4.47714
# Epoque  1283
# l'erreur est :  4.47713
# Epoque  1284
# l'erreur est :  4.47713
# Epoque  1285
# l'erreur est :  4.47713
# Epoque  1286
# l'erreur est :  4.47713
# Epoque  1287
# l'erreur est :  4.47713
# Epoque  1288
# l'erreur est :  4.47713
# Epoque  1289
# l'erreur est :  4.47713
# Epoque  1290
# l'erreur est :  4.47713
# Epoque  1291
# l'erreur est :  4.47713
# Epoque  1292
# l'erreur est :  4.47712
# Epoque  1293
# l'erreur est :  4.47712
# Epoque  1294
# l'erreur est :  4.47712
# Epoque  1295
# l'erreur est :  4.47712
# Epoque  1296
# l'erreur est :  4.47712
# Epoque  1297
# l'erreur est :  4.47712
# Epoque  1298
# l'erreur est :  4.47712
# Epoque  1299
# l'erreur est :  4.47712
# Epoque  1300
# l'erreur est :  4.47712
# Epoque  1301
# l'erreur est :  4.47711
# Epoque  1302
# l'erreur est :  4.47711
# Epoque  1303
# l'erreur est :  4.47711
# Epoque  1304
# l'erreur est :  4.47711
# Epoque  1305
# l'erreur est :  4.47711
# Epoque  1306
# l'erreur est :  4.47711
# Epoque  1307
# l'erreur est :  4.47711
# Epoque  1308
# l'erreur est :  4.47711
# Epoque  1309
# l'erreur est :  4.47711
# Epoque  1310
# l'erreur est :  4.47711
# Epoque  1311
# l'erreur est :  4.47710
# Epoque  1312
# l'erreur est :  4.47710
# Epoque  1313
# l'erreur est :  4.47710
# Epoque  1314
# l'erreur est :  4.47710
# Epoque  1315
# l'erreur est :  4.47710
# Epoque  1316
# l'erreur est :  4.47710
# Epoque  1317
# l'erreur est :  4.47710
# Epoque  1318
# l'erreur est :  4.47710
# Epoque  1319
# l'erreur est :  4.47710
# Epoque  1320
# l'erreur est :  4.47710
# Epoque  1321
# l'erreur est :  4.47710
# Epoque  1322
# l'erreur est :  4.47709
# Epoque  1323
# l'erreur est :  4.47709
# Epoque  1324
# l'erreur est :  4.47709
# Epoque  1325
# l'erreur est :  4.47709
# Epoque  1326
# l'erreur est :  4.47709
# Epoque  1327
# l'erreur est :  4.47709
# Epoque  1328
# l'erreur est :  4.47709
# Epoque  1329
# l'erreur est :  4.47709
# Epoque  1330
# l'erreur est :  4.47709
# Epoque  1331
# l'erreur est :  4.47709
# Epoque  1332
# l'erreur est :  4.47709
# Epoque  1333
# l'erreur est :  4.47709
# Epoque  1334
# l'erreur est :  4.47708
# Epoque  1335
# l'erreur est :  4.47708
# Epoque  1336
# l'erreur est :  4.47708
# Epoque  1337
# l'erreur est :  4.47708
# Epoque  1338
# l'erreur est :  4.47708
# Epoque  1339
# l'erreur est :  4.47708
# Epoque  1340
# l'erreur est :  4.47708
# Epoque  1341
# l'erreur est :  4.47708
# Epoque  1342
# l'erreur est :  4.47708
# Epoque  1343
# l'erreur est :  4.47708
# Epoque  1344
# l'erreur est :  4.47708
# Epoque  1345
# l'erreur est :  4.47708
# Epoque  1346
# l'erreur est :  4.47707
# Epoque  1347
# l'erreur est :  4.47707
# Epoque  1348
# l'erreur est :  4.47707
# Epoque  1349
# l'erreur est :  4.47707
# Epoque  1350
# l'erreur est :  4.47707
# Epoque  1351
# l'erreur est :  4.47707
# Epoque  1352
# l'erreur est :  4.47707
# Epoque  1353
# l'erreur est :  4.47707
# Epoque  1354
# l'erreur est :  4.47707
# Epoque  1355
# l'erreur est :  4.47707
# Epoque  1356
# l'erreur est :  4.47707
# Epoque  1357
# l'erreur est :  4.47707
# Epoque  1358
# l'erreur est :  4.47707
# Epoque  1359
# l'erreur est :  4.47707
# Epoque  1360
# l'erreur est :  4.47706
# Epoque  1361
# l'erreur est :  4.47706
# Epoque  1362
# l'erreur est :  4.47706
# Epoque  1363
# l'erreur est :  4.47706
# Epoque  1364
# l'erreur est :  4.47706
# Epoque  1365
# l'erreur est :  4.47706
# Epoque  1366
# l'erreur est :  4.47706
# Epoque  1367
# l'erreur est :  4.47706
# Epoque  1368
# l'erreur est :  4.47706
# Epoque  1369
# l'erreur est :  4.47706
# Epoque  1370
# l'erreur est :  4.47706
# Epoque  1371
# l'erreur est :  4.47706
# Epoque  1372
# l'erreur est :  4.47706
# Epoque  1373
# l'erreur est :  4.47706
# Epoque  1374
# l'erreur est :  4.47706
# Epoque  1375
# l'erreur est :  4.47706
# Epoque  1376
# l'erreur est :  4.47705
# Epoque  1377
# l'erreur est :  4.47705
# Epoque  1378
# l'erreur est :  4.47705
# Epoque  1379
# l'erreur est :  4.47705
# Epoque  1380
# l'erreur est :  4.47705
# Epoque  1381
# l'erreur est :  4.47705
# Epoque  1382
# l'erreur est :  4.47705
# Epoque  1383
# l'erreur est :  4.47705
# Epoque  1384
# l'erreur est :  4.47705
# Epoque  1385
# l'erreur est :  4.47705
# Epoque  1386
# l'erreur est :  4.47705
# Epoque  1387
# l'erreur est :  4.47705
# Epoque  1388
# l'erreur est :  4.47705
# Epoque  1389
# l'erreur est :  4.47705
# Epoque  1390
# l'erreur est :  4.47705
# Epoque  1391
# l'erreur est :  4.47705
# Epoque  1392
# l'erreur est :  4.47705
# Epoque  1393
# l'erreur est :  4.47705
# Epoque  1394
# l'erreur est :  4.47704
# Epoque  1395
# l'erreur est :  4.47704
# Epoque  1396
# l'erreur est :  4.47704
# Epoque  1397
# l'erreur est :  4.47704
# Epoque  1398
# l'erreur est :  4.47704
# Epoque  1399
# l'erreur est :  4.47704
# Epoque  1400
# l'erreur est :  4.47704
# Epoque  1401
# l'erreur est :  4.47704
# Epoque  1402
# l'erreur est :  4.47704
# Epoque  1403
# l'erreur est :  4.47704
# Epoque  1404
# l'erreur est :  4.47704
# Epoque  1405
# l'erreur est :  4.47704
# Epoque  1406
# l'erreur est :  4.47704
# Epoque  1407
# l'erreur est :  4.47704
# Epoque  1408
# l'erreur est :  4.47704
# Epoque  1409
# l'erreur est :  4.47704
# Epoque  1410
# l'erreur est :  4.47704
# Epoque  1411
# l'erreur est :  4.47704
# Epoque  1412
# l'erreur est :  4.47704
# Epoque  1413
# l'erreur est :  4.47704
# Epoque  1414
# l'erreur est :  4.47703
# Epoque  1415
# l'erreur est :  4.47703
# Epoque  1416
# l'erreur est :  4.47703
# Epoque  1417
# l'erreur est :  4.47703
# Epoque  1418
# l'erreur est :  4.47703
# Epoque  1419
# l'erreur est :  4.47703
# Epoque  1420
# l'erreur est :  4.47703
# Epoque  1421
# l'erreur est :  4.47703
# Epoque  1422
# l'erreur est :  4.47703
# Epoque  1423
# l'erreur est :  4.47703
# Epoque  1424
# l'erreur est :  4.47703
# Epoque  1425
# l'erreur est :  4.47703
# Epoque  1426
# l'erreur est :  4.47703
# Epoque  1427
# l'erreur est :  4.47703
# Epoque  1428
# l'erreur est :  4.47703
# Epoque  1429
# l'erreur est :  4.47703
# Epoque  1430
# l'erreur est :  4.47703
# Epoque  1431
# l'erreur est :  4.47703
# Epoque  1432
# l'erreur est :  4.47703
# Epoque  1433
# l'erreur est :  4.47703
# Epoque  1434
# l'erreur est :  4.47703
# Epoque  1435
# l'erreur est :  4.47703
# Epoque  1436
# l'erreur est :  4.47703
# Epoque  1437
# l'erreur est :  4.47702
# Epoque  1438
# l'erreur est :  4.47702
# Epoque  1439
# l'erreur est :  4.47702
# Epoque  1440
# l'erreur est :  4.47702
# Epoque  1441
# l'erreur est :  4.47702
# Epoque  1442
# l'erreur est :  4.47702
# Epoque  1443
# l'erreur est :  4.47702
# Epoque  1444
# l'erreur est :  4.47702
# Epoque  1445
# l'erreur est :  4.47702
# Epoque  1446
# l'erreur est :  4.47702
# Epoque  1447
# l'erreur est :  4.47702
# Epoque  1448
# l'erreur est :  4.47702
# Epoque  1449
# l'erreur est :  4.47702
# Epoque  1450
# l'erreur est :  4.47702
# Epoque  1451
# l'erreur est :  4.47702
# Epoque  1452
# l'erreur est :  4.47702
# Epoque  1453
# l'erreur est :  4.47702
# Epoque  1454
# l'erreur est :  4.47702
# Epoque  1455
# l'erreur est :  4.47702
# Epoque  1456
# l'erreur est :  4.47702
# Epoque  1457
# l'erreur est :  4.47702
# Epoque  1458
# l'erreur est :  4.47702
# Epoque  1459
# l'erreur est :  4.47702
# Epoque  1460
# l'erreur est :  4.47702
# Epoque  1461
# l'erreur est :  4.47702
# Epoque  1462
# l'erreur est :  4.47702
# Epoque  1463
# l'erreur est :  4.47702
# Epoque  1464
# l'erreur est :  4.47702
# Epoque  1465
# l'erreur est :  4.47702
# Epoque  1466
# l'erreur est :  4.47701
# Epoque  1467
# l'erreur est :  4.47701
# Epoque  1468
# l'erreur est :  4.47701
# Epoque  1469
# l'erreur est :  4.47701
# Epoque  1470
# l'erreur est :  4.47701
# Epoque  1471
# l'erreur est :  4.47701
# Epoque  1472
# l'erreur est :  4.47701
# Epoque  1473
# l'erreur est :  4.47701
# Epoque  1474
# l'erreur est :  4.47701
# Epoque  1475
# l'erreur est :  4.47701
# Epoque  1476
# l'erreur est :  4.47701
# Epoque  1477
# l'erreur est :  4.47701
# Epoque  1478
# l'erreur est :  4.47701
# Epoque  1479
# l'erreur est :  4.47701
# Epoque  1480
# l'erreur est :  4.47701
# Epoque  1481
# l'erreur est :  4.47701
# Epoque  1482
# l'erreur est :  4.47701
# Epoque  1483
# l'erreur est :  4.47701
# Epoque  1484
# l'erreur est :  4.47701
# Epoque  1485
# l'erreur est :  4.47701
# Epoque  1486
# l'erreur est :  4.47701
# Epoque  1487
# l'erreur est :  4.47701
# Epoque  1488
# l'erreur est :  4.47701
# Epoque  1489
# l'erreur est :  4.47701
# Epoque  1490
# l'erreur est :  4.47701
# Epoque  1491
# l'erreur est :  4.47701
# Epoque  1492
# l'erreur est :  4.47701
# Epoque  1493
# l'erreur est :  4.47701
# Epoque  1494
# l'erreur est :  4.47701
# Epoque  1495
# l'erreur est :  4.47701
# Epoque  1496
# l'erreur est :  4.47701
# Epoque  1497
# l'erreur est :  4.47701
# Epoque  1498
# l'erreur est :  4.47701
# Epoque  1499
# l'erreur est :  4.47701
# 3.401265234280818

# %% [markdown]
# on a trouvé le vecteur theta suivant :

# %%
print(theta_train)
# Out:
# [-3.87638227  1.19108484]

# %% [markdown]
# pour calculer le profit d'un nouveau food truck sur une ville de 1000 habitants, on fera :

# %%
x = np.array([1, 1000])
profit = h_theta(x,theta_train)
print("Pour une ville de 1000 habitants, le profit est estimé à : ","%.2f"%profit,"$")
# Out:
# Pour une ville de 1000 habitants, le profit est estimé à :  1187.21 $

# %% [markdown]
# # Annexe :

# %% [markdown]
# ### passage de l'implementation scalaire à l'implementation vectorielle

# %% [markdown]
# on peut demontrer $$ h_\Theta (x) = \Theta_0 + \Theta_1 x = \Theta_0 * 1 + \Theta_1 * x $$

# %% [markdown]
# $$ comme \hspace{0.2cm} x_0 = 1 \hspace{0.2cm} et \hspace{0.2cm} x_1 = x, \hspace{0.3cm} on \hspace{0.3cm} peut \hspace{0.3cm} ecrire \hspace{0.3cm} h_\Theta (x) = \Theta_0 * x_0 + \Theta_1 * x_1 $$

# %% [markdown]
# $$ce \hspace{0.2cm} qui \hspace{0.2cm} nous \hspace{0.2cm} donne \hspace{0.2cm} h_\Theta (x) = \bigl(\begin{smallmatrix}
#  \Theta_0& \Theta_1
# \end{smallmatrix}\bigr) * \binom{x_0}{x_1} = \Theta^Tx $$

# %% [markdown]
# $$ h_\Theta (x) = \Theta^T x $$
